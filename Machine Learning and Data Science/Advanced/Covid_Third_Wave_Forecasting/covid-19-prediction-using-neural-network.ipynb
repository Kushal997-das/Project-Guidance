# %% [markdown]
# <a href="https://www.kaggle.com/shiv28/covid-19-prediction-using-neural-network?scriptVersionId=88435809" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ## **Covid-19 prediction using Neural Network**

# %% [markdown]
# ## Abstract

# %% [markdown]
# This notebook is devoted to predicting the COVID-19 spread dynamics in the world using neural networks of different structures. We will see how to make predictions based on linear regression, back propagation  and long short-term memory neural networks

# %% [markdown]
# ## Introduction

# %% [markdown]
# Today there is a lot of open data about the spread of COVID-19 in the world. However, few tools are presented to predict  these processes.
#
# 3 different mathematical models for the forecast calculation will taken.
#
# To do this, the division of the DataSet into training and test sets will be demonstrated, normalize data and make preliminary analysis.
#
# It will be shown how to build models and DataSets for using 2 different neural networks.
#
# The next step is to compare the accuracy and adequacy of the obtained models.

# %% [markdown]
# ## Steps or Stages

# %% [markdown]
# It consists of four stages:
#
# *   Download and preliminary analysis of data
# *   Linear Regression
# *   Back Propagation NN
# *   Long Short-Term Memory - LSTM

# %% [markdown]
# In first stage we pre-prepare data for analysis:
#
# *   change the data types of columns
# *   rows filtering
# *   elimination of missing data
# *   DataSet transformation
# *   data normalization
#
# During the next steps, we will demonstrate 3 different models .

# %% [markdown]
# ## Prerequisites
#
# *   Python
# *   Pandas
# *   Statistics
# *   NumPy
# *   Matplotlib
# *   Keras
# *   Scikit-Learn

# %% [markdown]
# ## Objectives

# %% [markdown]
# ## Required libraries Importing

# %% [markdown]
# Some libraries should be imported .

# %%
import pandas as pd
import numpy as np

# %%
covid_word = pd.read_csv('../input/covidowid/owid-covid-data.csv')
covid_word
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 159316      ZWE    Africa     Zimbabwe  2022-01-30     229460.0       45.0
# 159317      ZWE    Africa     Zimbabwe  2022-01-31     229666.0      206.0
# 159318      ZWE    Africa     Zimbabwe  2022-02-01     229851.0      185.0
# 159319      ZWE    Africa     Zimbabwe  2022-02-02     230012.0      161.0
# 159320      ZWE    Africa     Zimbabwe  2022-02-03     230170.0      158.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         NaN                  NaN
# 1                      NaN           NaN         NaN                  NaN
# 2                      NaN           NaN         NaN                  NaN
# 3                      NaN           NaN         NaN                  NaN
# 4                      NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 159316             172.286        5337.0         4.0                6.143
# 159317             160.714        5338.0         1.0                4.714
# 159318             153.571        5350.0        12.0                4.857
# 159319             152.714        5352.0         2.0                4.429
# 159320             153.429        5357.0         5.0                4.714
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 0       ...             NaN           NaN                  37.746
# 1       ...             NaN           NaN                  37.746
# 2       ...             NaN           NaN                  37.746
# 3       ...             NaN           NaN                  37.746
# 4       ...             NaN           NaN                  37.746
# ...     ...             ...           ...                     ...
# 159316  ...             1.6          30.7                  36.791
# 159317  ...             1.6          30.7                  36.791
# 159318  ...             1.6          30.7                  36.791
# 159319  ...             1.6          30.7                  36.791
# 159320  ...             1.6          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                              0.5            64.83                    0.511
# 1                              0.5            64.83                    0.511
# 2                              0.5            64.83                    0.511
# 3                              0.5            64.83                    0.511
# 4                              0.5            64.83                    0.511
# ...                            ...              ...                      ...
# 159316                         1.7            61.49                    0.571
# 159317                         1.7            61.49                    0.571
# 159318                         1.7            61.49                    0.571
# 159319                         1.7            61.49                    0.571
# 159320                         1.7            61.49                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 159316                                   NaN                          NaN
# 159317                                   NaN                          NaN
# 159318                                   NaN                          NaN
# 159319                                   NaN                          NaN
# 159320                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 159316               NaN                                      NaN
# 159317               NaN                                      NaN
# 159318               NaN                                      NaN
# 159319               NaN                                      NaN
# 159320               NaN                                      NaN
#
# [159321 rows x 67 columns]

# %% [markdown]
# Let's study our DataSet. As you can see, it consist of 159321 rows × 67 columns. There is some missing data are observed in the DataSet. We should be sure that Python recognized types of data correctly.

# %%
covid_word.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159321 entries, 0 to 159320
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    159321 non-null  object
#  1   continent                                   149755 non-null  object
#  2   location                                    159321 non-null  object
#  3   date                                        159321 non-null  object
#  4   total_cases                                 156450 non-null  float64
#  5   new_cases                                   156400 non-null  float64
#  6   new_cases_smoothed                          155249 non-null  float64
#  7   total_deaths                                138892 non-null  float64
#  8   new_deaths                                  139060 non-null  float64
#  9   new_deaths_smoothed                         138930 non-null  float64
#  10  total_cases_per_million                     155722 non-null  float64
#  11  new_cases_per_million                       155672 non-null  float64
#  12  new_cases_smoothed_per_million              154526 non-null  float64
#  13  total_deaths_per_million                    138177 non-null  float64
#  14  new_deaths_per_million                      138345 non-null  float64
#  15  new_deaths_smoothed_per_million             138215 non-null  float64
#  16  reproduction_rate                           120151 non-null  float64
#  17  icu_patients                                22394 non-null   float64
#  18  icu_patients_per_million                    22394 non-null   float64
#  19  hosp_patients                               23085 non-null   float64
#  20  hosp_patients_per_million                   23085 non-null   float64
#  21  weekly_icu_admissions                       5102 non-null    float64
#  22  weekly_icu_admissions_per_million           5102 non-null    float64
#  23  weekly_hosp_admissions                      10344 non-null   float64
#  24  weekly_hosp_admissions_per_million          10344 non-null   float64
#  25  new_tests                                   65436 non-null   float64
#  26  total_tests                                 66568 non-null   float64
#  27  total_tests_per_thousand                    66568 non-null   float64
#  28  new_tests_per_thousand                      65436 non-null   float64
#  29  new_tests_smoothed                          81092 non-null   float64
#  30  new_tests_smoothed_per_thousand             80366 non-null   float64
#  31  positive_rate                               76216 non-null   float64
#  32  tests_per_case                              75452 non-null   float64
#  33  tests_units                                 82578 non-null   object
#  34  total_vaccinations                          42341 non-null   float64
#  35  people_vaccinated                           40318 non-null   float64
#  36  people_fully_vaccinated                     37405 non-null   float64
#  37  total_boosters                              14761 non-null   float64
#  38  new_vaccinations                            35171 non-null   float64
#  39  new_vaccinations_smoothed                   77682 non-null   float64
#  40  total_vaccinations_per_hundred              42341 non-null   float64
#  41  people_vaccinated_per_hundred               40318 non-null   float64
#  42  people_fully_vaccinated_per_hundred         37405 non-null   float64
#  43  total_boosters_per_hundred                  14761 non-null   float64
#  44  new_vaccinations_smoothed_per_million       77682 non-null   float64
#  45  new_people_vaccinated_smoothed              76540 non-null   float64
#  46  new_people_vaccinated_smoothed_per_hundred  76540 non-null   float64
#  47  stringency_index                            124732 non-null  float64
#  48  population                                  158276 non-null  float64
#  49  population_density                          141815 non-null  float64
#  50  median_age                                  132166 non-null  float64
#  51  aged_65_older                               130732 non-null  float64
#  52  aged_70_older                               131457 non-null  float64
#  53  gdp_per_capita                              132781 non-null  float64
#  54  extreme_poverty                             87500 non-null   float64
#  55  cardiovasc_death_rate                       131143 non-null  float64
#  56  diabetes_prevalence                         138014 non-null  float64
#  57  female_smokers                              101705 non-null  float64
#  58  male_smokers                                100245 non-null  float64
#  59  handwashing_facilities                      65692 non-null   float64
#  60  hospital_beds_per_thousand                  118599 non-null  float64
#  61  life_expectancy                             148711 non-null  float64
#  62  human_development_index                     130618 non-null  float64
#  63  excess_mortality_cumulative_absolute        5460 non-null    float64
#  64  excess_mortality_cumulative                 5460 non-null    float64
#  65  excess_mortality                            5460 non-null    float64
#  66  excess_mortality_cumulative_per_million     5460 non-null    float64
# dtypes: float64(62), object(5)
# memory usage: 81.4+ MB

# %% [markdown]
# As you can see, 66 columns of COVID-19 data were recognized correctly (float64). First 4 columns and tests_units were recognized as objects. Let's investigate them:

# %%
fields = ['iso_code', 'continent', 'location', 'tests_units']
covid_word[fields]
# Out:
#        iso_code continent     location      tests_units
# 0           AFG      Asia  Afghanistan              NaN
# 1           AFG      Asia  Afghanistan              NaN
# 2           AFG      Asia  Afghanistan              NaN
# 3           AFG      Asia  Afghanistan              NaN
# 4           AFG      Asia  Afghanistan              NaN
# ...         ...       ...          ...              ...
# 159316      ZWE    Africa     Zimbabwe  tests performed
# 159317      ZWE    Africa     Zimbabwe  tests performed
# 159318      ZWE    Africa     Zimbabwe              NaN
# 159319      ZWE    Africa     Zimbabwe              NaN
# 159320      ZWE    Africa     Zimbabwe              NaN
#
# [159321 rows x 4 columns]

# %% [markdown]
# Let's show information about the field date.

# %%
covid_word['date']
# Out:
# 0         2020-02-24
# 1         2020-02-25
# 2         2020-02-26
# 3         2020-02-27
# 4         2020-02-28
#              ...
# 159316    2022-01-30
# 159317    2022-01-31
# 159318    2022-02-01
# 159319    2022-02-02
# 159320    2022-02-03
# Name: date, Length: 159321, dtype: object

# %% [markdown]
# ### Сhange the data types of columns

# %% [markdown]
# As you can see, the columns: 'iso_code', 'continent', 'location', 'tests_units' have many repetitions and should be assigned to categorical fields **pandas.astype()**.
#
# The field 'data' should be converted into DataTime type **pandas.to_datetime**
# To see the results we can use **pandas.describe()**.

# %%
fields = ['iso_code', 'continent', 'location', 'tests_units']
covid_word[fields] =covid_word[fields].astype('category')
covid_word.loc[:, 'date'] = pd.to_datetime(covid_word['date'])
covid_word[fields].describe()
# Out:
#        iso_code continent location      tests_units
# count    159321    149755   159321            82578
# unique      238         6      238                4
# top         PER    Africa   Mexico  tests performed
# freq        765     37767      765            57552

# %% [markdown]
# ### Rows filtering

# %% [markdown]
# As we can see, the DataSet contains information about 6 continents and 238 countries.
# The field 'tests_units' consist of 4 categories. To show a list of countries, we can use **pandas.Series.cat.categories**.

# %%
covid_word['location'].cat.categories
# Out:
# Index(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia',
#        ...
#        'Uzbekistan', 'Vanuatu', 'Vatican', 'Venezuela', 'Vietnam',
#        'Wallis and Futuna', 'World', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', length=238)

# %% [markdown]
# Let's investigate the dynamics of new cases of COVID-19 for a separate country. We will use India for saving models and further forecast. You can use your country. Let's use a pandas filter to do this.

# %%
covid_word.index = covid_word['date']
c_covid = covid_word[covid_word['location'] == "India"]
c_covid
# Out:
#            iso_code continent location       date  total_cases  new_cases  \
# date
# 2020-01-30      IND      Asia    India 2020-01-30          1.0        1.0
# 2020-01-31      IND      Asia    India 2020-01-31          1.0        0.0
# 2020-02-01      IND      Asia    India 2020-02-01          1.0        0.0
# 2020-02-02      IND      Asia    India 2020-02-02          2.0        1.0
# 2020-02-03      IND      Asia    India 2020-02-03          3.0        1.0
# ...             ...       ...      ...        ...          ...        ...
# 2022-01-30      IND      Asia    India 2022-01-30   41302440.0   209918.0
# 2022-01-31      IND      Asia    India 2022-01-31   41469499.0   167059.0
# 2022-02-01      IND      Asia    India 2022-02-01   41630885.0   161386.0
# 2022-02-02      IND      Asia    India 2022-02-02   41803318.0   172433.0
# 2022-02-03      IND      Asia    India 2022-02-03   41803318.0        NaN
#
#             new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# date
# 2020-01-30                 NaN           NaN         NaN                  NaN
# 2020-01-31                 NaN           NaN         NaN                  NaN
# 2020-02-01                 NaN           NaN         NaN                  NaN
# 2020-02-02                 NaN           NaN         NaN                  NaN
# 2020-02-03                 NaN           NaN         NaN                  NaN
# ...                        ...           ...         ...                  ...
# 2022-01-30          251301.714      495050.0       959.0              743.143
# 2022-01-31          238613.857      496242.0      1192.0              825.714
# 2022-02-01          220824.143      497975.0      1733.0              978.286
# 2022-02-02          204545.429      498983.0      1008.0             1040.429
# 2022-02-03                 NaN      498983.0         NaN                  NaN
#
#             ...  female_smokers  male_smokers  handwashing_facilities  \
# date        ...
# 2020-01-30  ...             1.9          20.6                   59.55
# 2020-01-31  ...             1.9          20.6                   59.55
# 2020-02-01  ...             1.9          20.6                   59.55
# 2020-02-02  ...             1.9          20.6                   59.55
# 2020-02-03  ...             1.9          20.6                   59.55
# ...         ...             ...           ...                     ...
# 2022-01-30  ...             1.9          20.6                   59.55
# 2022-01-31  ...             1.9          20.6                   59.55
# 2022-02-01  ...             1.9          20.6                   59.55
# 2022-02-02  ...             1.9          20.6                   59.55
# 2022-02-03  ...             1.9          20.6                   59.55
#
#             hospital_beds_per_thousand  life_expectancy  \
# date
# 2020-01-30                        0.53            69.66
# 2020-01-31                        0.53            69.66
# 2020-02-01                        0.53            69.66
# 2020-02-02                        0.53            69.66
# 2020-02-03                        0.53            69.66
# ...                                ...              ...
# 2022-01-30                        0.53            69.66
# 2022-01-31                        0.53            69.66
# 2022-02-01                        0.53            69.66
# 2022-02-02                        0.53            69.66
# 2022-02-03                        0.53            69.66
#
#             human_development_index  excess_mortality_cumulative_absolute  \
# date
# 2020-01-30                    0.645                                   NaN
# 2020-01-31                    0.645                                   NaN
# 2020-02-01                    0.645                                   NaN
# 2020-02-02                    0.645                                   NaN
# 2020-02-03                    0.645                                   NaN
# ...                             ...                                   ...
# 2022-01-30                    0.645                                   NaN
# 2022-01-31                    0.645                                   NaN
# 2022-02-01                    0.645                                   NaN
# 2022-02-02                    0.645                                   NaN
# 2022-02-03                    0.645                                   NaN
#
#             excess_mortality_cumulative  excess_mortality  \
# date
# 2020-01-30                          NaN               NaN
# 2020-01-31                          NaN               NaN
# 2020-02-01                          NaN               NaN
# 2020-02-02                          NaN               NaN
# 2020-02-03                          NaN               NaN
# ...                                 ...               ...
# 2022-01-30                          NaN               NaN
# 2022-01-31                          NaN               NaN
# 2022-02-01                          NaN               NaN
# 2022-02-02                          NaN               NaN
# 2022-02-03                          NaN               NaN
#
#             excess_mortality_cumulative_per_million
# date
# 2020-01-30                                      NaN
# 2020-01-31                                      NaN
# 2020-02-01                                      NaN
# 2020-02-02                                      NaN
# 2020-02-03                                      NaN
# ...                                             ...
# 2022-01-30                                      NaN
# 2022-01-31                                      NaN
# 2022-02-01                                      NaN
# 2022-02-02                                      NaN
# 2022-02-03                                      NaN
#
# [736 rows x 67 columns]

# %% [markdown]
# Let's choose the fields 'new_cases', 'new_cases_smoothed' for forecasting. First of all, we should visualize this data.

# %%
import matplotlib.pyplot as plt
fields = ['new_cases', 'new_cases_smoothed']
c_covid[fields].plot()
plt.show()

# %% [markdown]
# ### Elimination of missing data

# %% [markdown]
# As you can see, there are large fluctuations in the new cases plot. Let's try to make a forecast for these waves.
# First of all, we should delete missing data using **pandas.DataFrame.dropna()**

# %%
c_covid = c_covid[fields].dropna()
c_covid
# Out:
#             new_cases  new_cases_smoothed
# date
# 2020-02-04        0.0               0.429
# 2020-02-05        0.0               0.429
# 2020-02-06        0.0               0.286
# 2020-02-07        0.0               0.286
# 2020-02-08        0.0               0.286
# ...               ...                 ...
# 2022-01-29   234281.0          265036.857
# 2022-01-30   209918.0          251301.714
# 2022-01-31   167059.0          238613.857
# 2022-02-01   161386.0          220824.143
# 2022-02-02   172433.0          204545.429
#
# [730 rows x 2 columns]

# %% [markdown]
# ### Data transformation

# %% [markdown]
#  To check for dependencies, it is necessary to perform a correlation analysis between them. This requires:
#
# 1.  duplicating of data and moving it vertically down for a certain number of days (lag)
# 2.  deleting the missing data at the beginning and end **pandas.DataFrame.shift()**
# 3.  calculating the correlation coefficient between the obtained series.
#
# It is convenient to create a separate function for lag:

# %%
def lag_correlation_ts(y, x, lag):
    """
   
    y: fixed
    x: shifted
    lag: lag for shifting
    r: DataFrame of lags correlation coefficients
    """
    r = [0] * (lag + 1)
    y = y.copy()
    x = x.copy()
    y.name = "y"
    x.name = "x"

    for i in range(0, lag + 1):
        ds = y.copy().to_frame()
        ds = ds.join(x.shift(i), how='outer')
        r[i] = ds.corr().values[0][1]
    r = pd.DataFrame(r)
    r.index.names = ['Lag']
    r.columns = ['Correlation']
    return r

# %% [markdown]
# Let's create a target DataSet.

# %%
y_dataset = c_covid['new_cases']
y_dataset
# Out:
# date
# 2020-02-04         0.0
# 2020-02-05         0.0
# 2020-02-06         0.0
# 2020-02-07         0.0
# 2020-02-08         0.0
#                 ...
# 2022-01-29    234281.0
# 2022-01-30    209918.0
# 2022-01-31    167059.0
# 2022-02-01    161386.0
# 2022-02-02    172433.0
# Name: new_cases, Length: 730, dtype: float64

# %% [markdown]
# Let's test a 50-day lag.

# %%
pd.options.display.float_format = '{:,.4f}'.format
l = pd.DataFrame(lag_correlation_ts(y_dataset, y_dataset, 50)) 
print(l)
l.plot()
# Out:
#      Correlation
# Lag
# 0         1.0000
# 1         0.9229
# 2         0.9637
# 3         0.9265
# 4         0.9278
# 5         0.9188
# 6         0.9108
# 7         0.8966
# 8         0.8776
# 9         0.8539
# 10        0.8319
# 11        0.8141
# 12        0.7918
# 13        0.7738
# 14        0.7529
# 15        0.7255
# 16        0.6971
# 17        0.6698
# 18        0.6440
# 19        0.6178
# 20        0.6003
# 21        0.5788
# 22        0.5518
# 23        0.5260
# 24        0.5001
# 25        0.4734
# 26        0.4484
# 27        0.4255
# 28        0.4018
# 29        0.3771
# 30        0.3534
# 31        0.3321
# 32        0.3112
# 33        0.2913
# 34        0.2730
# 35        0.2549
# 36        0.2344
# 37        0.2146
# 38        0.1984
# 39        0.1796
# 40        0.1653
# 41        0.1493
# 42        0.1353
# 43        0.1188
# 44        0.1032
# 45        0.0895
# 46        0.0760
# 47        0.0632
# 48        0.0526
# 49        0.0413
# 50        0.0287
# <AxesSubplot:xlabel='Lag'>

# %% [markdown]
# To automate this process, let's make a universal function for time series transformation to create this DataSet.

# %%
def series_to_supervised(in_data, tar_data, n_in=1, dropnan=True, target_dep=False):

    n_vars = in_data.shape[1]
    cols, names = list(), list()

    if target_dep:
        i_start = 1
    else:
        i_start = 0
    for i in range(i_start, n_in + 1):
        cols.append(in_data.shift(i))
        names += [('%s(t-%d)' % (in_data.columns[j], i)) for j in range(n_vars)]

    if target_dep:
        for i in range(n_in, -1, -1):
            cols.append(tar_data.shift(i))
            names += [('%s(t-%d)' % (tar_data.name, i))]
    else:
        # put it all together
        cols.append(tar_data)
        names.append(tar_data.name)
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)

    return agg

# %% [markdown]
#  When forecasting time series, the input and output fields are the same, only shifted by the lag.

# %%
dataset = series_to_supervised(pd.DataFrame(y_dataset), y_dataset, 14)
dataset
# Out:
#             new_cases(t-0)  new_cases(t-1)  new_cases(t-2)  new_cases(t-3)  \
# date
# 2020-02-18          0.0000          0.0000          0.0000          0.0000
# 2020-02-19          0.0000          0.0000          0.0000          0.0000
# 2020-02-20          0.0000          0.0000          0.0000          0.0000
# 2020-02-21          0.0000          0.0000          0.0000          0.0000
# 2020-02-22          0.0000          0.0000          0.0000          0.0000
# ...                    ...             ...             ...             ...
# 2022-01-29    234,281.0000    235,532.0000    251,209.0000    286,384.0000
# 2022-01-30    209,918.0000    234,281.0000    235,532.0000    251,209.0000
# 2022-01-31    167,059.0000    209,918.0000    234,281.0000    235,532.0000
# 2022-02-01    161,386.0000    167,059.0000    209,918.0000    234,281.0000
# 2022-02-02    172,433.0000    161,386.0000    167,059.0000    209,918.0000
#
#             new_cases(t-4)  new_cases(t-5)  new_cases(t-6)  new_cases(t-7)  \
# date
# 2020-02-18          0.0000          0.0000          0.0000          0.0000
# 2020-02-19          0.0000          0.0000          0.0000          0.0000
# 2020-02-20          0.0000          0.0000          0.0000          0.0000
# 2020-02-21          0.0000          0.0000          0.0000          0.0000
# 2020-02-22          0.0000          0.0000          0.0000          0.0000
# ...                    ...             ...             ...             ...
# 2022-01-29    285,914.0000    255,874.0000    306,064.0000    333,533.0000
# 2022-01-30    286,384.0000    285,914.0000    255,874.0000    306,064.0000
# 2022-01-31    251,209.0000    286,384.0000    285,914.0000    255,874.0000
# 2022-02-01    235,532.0000    251,209.0000    286,384.0000    285,914.0000
# 2022-02-02    234,281.0000    235,532.0000    251,209.0000    286,384.0000
#
#             new_cases(t-8)  new_cases(t-9)  new_cases(t-10)  new_cases(t-11)  \
# date
# 2020-02-18          0.0000          0.0000           0.0000           0.0000
# 2020-02-19          0.0000          0.0000           0.0000           0.0000
# 2020-02-20          0.0000          0.0000           0.0000           0.0000
# 2020-02-21          0.0000          0.0000           0.0000           0.0000
# 2020-02-22          0.0000          0.0000           0.0000           0.0000
# ...                    ...             ...              ...              ...
# 2022-01-29    337,704.0000    347,254.0000     317,532.0000     282,970.0000
# 2022-01-30    333,533.0000    337,704.0000     347,254.0000     317,532.0000
# 2022-01-31    306,064.0000    333,533.0000     337,704.0000     347,254.0000
# 2022-02-01    255,874.0000    306,064.0000     333,533.0000     337,704.0000
# 2022-02-02    285,914.0000    255,874.0000     306,064.0000     333,533.0000
#
#             new_cases(t-12)  new_cases(t-13)  new_cases(t-14)    new_cases
# date
# 2020-02-18           0.0000           0.0000           0.0000       0.0000
# 2020-02-19           0.0000           0.0000           0.0000       0.0000
# 2020-02-20           0.0000           0.0000           0.0000       0.0000
# 2020-02-21           0.0000           0.0000           0.0000       0.0000
# 2020-02-22           0.0000           0.0000           0.0000       0.0000
# ...                     ...              ...              ...          ...
# 2022-01-29     238,018.0000     258,089.0000     271,202.0000 234,281.0000
# 2022-01-30     282,970.0000     238,018.0000     258,089.0000 209,918.0000
# 2022-01-31     317,532.0000     282,970.0000     238,018.0000 167,059.0000
# 2022-02-01     347,254.0000     317,532.0000     282,970.0000 161,386.0000
# 2022-02-02     337,704.0000     347,254.0000     317,532.0000 172,433.0000
#
# [716 rows x 16 columns]

# %% [markdown]
# As you can see, the first and last columns contain the same target data.
# Now we should create input (**X**) and output (**Y**) .

# %%
col = dataset.columns
X, Y = dataset[col[1:-1]], dataset[col[-1]]
print("Input: ", X.columns)
print("Target:", Y.name)
# Out:
# Input:  Index(['new_cases(t-1)', 'new_cases(t-2)', 'new_cases(t-3)', 'new_cases(t-4)',
#        'new_cases(t-5)', 'new_cases(t-6)', 'new_cases(t-7)', 'new_cases(t-8)',
#        'new_cases(t-9)', 'new_cases(t-10)', 'new_cases(t-11)',
#        'new_cases(t-12)', 'new_cases(t-13)', 'new_cases(t-14)'],
#       dtype='object')
# Target: new_cases

# %% [markdown]
# ### Data normalization

# %% [markdown]
# After that, we should normalize all the data. To do this, the **sklearn.preprocessing.MinMaxScaler** module should be used.
# It allows us to normalize **fit_transform()** and convert back all the data easily: **inverse_transform()**.

# %%
from sklearn.preprocessing import MinMaxScaler
scaler_x = MinMaxScaler(feature_range=(0, 1))
scaler_y = MinMaxScaler(feature_range=(0, 1))

scaled_x = scaler_x.fit_transform(X)
scaled_y = scaler_y.fit_transform(Y.values.reshape(-1, 1))

# %% [markdown]
# After that, we are going to form training and test DataSets using **sklearn.model_selection.train_test_split()**.
#
# We will make them at the ratio of 73/27. Without shuffling. It means, that test samples are located in the end of **X** and **Y** DataSets.
#
# Input normalized DataSets: **X_train, X_test**
#
# Target normalized DataSets: **y_train, y_test**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(scaled_x, scaled_y, test_size=0.27, shuffle=False)

# %% [markdown]
# All the data is normalized now. However, in order to compare to results, we need real scale data of the training and test DataSet:

# %%
res_train = scaler_y.inverse_transform(y_train).flatten()
res_test = scaler_y.inverse_transform(y_test).flatten()

# %% [markdown]
# Target real scale DataSets: **res_train, res_test**.

# %% [markdown]
# # Linear Regression

# %% [markdown]
# First of all, we should create a model. We will test three type of models. A Linear regression, a Multilayer Neural Network with Backpropagation and a Long Short-Term Memory Neural Network.
# Let's create a **LinearRegression()**

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %% [markdown]
# After that, our model should be fitted on the training DataSet. Regardless of the model type, the function fit() is used to do this.

# %%
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Then we can test it on the test DataSet and use it for prognostication.

# %%
y_pred_test_ln = regressor.predict(X_test)
y_pred_test_ln = scaler_y.inverse_transform(y_pred_test_ln).flatten()

# %% [markdown]
# Let's analyze the results accuracy using **sklearn.metrics**.

# %%
from sklearn import metrics
print("Correlation train", regressor.score(X_train, y_train))
print("Correlation test", regressor.score(X_test, y_test))
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_test_ln))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_test_ln))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_test_ln)))
# Out:
# Correlation train 0.9967819135097542
# Correlation test 0.5553874228045524
# Mean Absolute Error: 54277.462667940854
# Mean Squared Error: 10920561768.866043
# Root Mean Squared Error: 104501.49170641557

# %% [markdown]
# # Back Propagation NN

# %% [markdown]
# The modern approach to the establishment of complex functional dependencies is the use of neural networks. A classical neural network is a **multilayer neural network with back propagation**.
#
# To do this, we will use the **keras** framework.
# First of all, we should create a Neural Network model as a separate function.
#
# A neural network is a sequence of layers. The function **Sequential()** is used to create a network.
#
# Let's create a network that consists of 2 hidden layers. Each of which consists of 100 neurons. **keras.layers.Dense()**.
#
# To avoid retraining problems, we will use additional layers **keras.layers.Dropout()**.
#
# The output layer will consist of one neuron, since we have only one value at the output.
#
# The model should be compiled for fitting and predicting: **keras.Model.compile()**.

# %%
def BP_model(X):
    """
    Multilayer neural network with back propagation.
    X: Input DataSet
    return: keras NN model
    """
    # create model
    model = Sequential() 
    model.add(Dense(100, input_dim=X.shape[1], kernel_initializer='normal', activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(100, kernel_initializer='normal', activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1, kernel_initializer='normal'))
    # Compile model
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %% [markdown]
# Once the model function is built, it is necessary to create a neural network directly and specify the learning parameters: **keras.wrappers.scikit_learn.KerasRegressor()**.
#
# Also we should define the number of fitting **epoch and batch size**.

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
epochs = 1000

batch_size=int(y_train.shape[0]*.1)

estimator = KerasRegressor(build_fn=BP_model, X=X_train, epochs=epochs, batch_size=batch_size, verbose=1)

# %% [markdown]
# Now, let’s train our model for **1000** epochs.
# It should be noted that the fitting process is very slow. Therefore, we saved our fitted model to a file.
# To save time, we will upload the fitted model.
# If you like, you can leave the parameter **fitting on True** to refit the model.
# If you like, you can leave the parameter **fitting_save on True** to resave the model.

# %%
fitting = True
fitting_save = True

import pickle

if fitting:
    history=estimator.fit(X_train,y_train, validation_data=(X_test,y_test)) # Fitting model
    if fitting_save:
        # Save model
        estimator.model.save('BP_saved_model.h5')
        print("Saved model to disk")
        with open('history.pickle', 'wb') as f:
            pickle.dump(history.history, f)
# load model 
from keras.models import load_model
estimator = KerasRegressor(build_fn=BP_model, X=X_train, epochs=epochs, batch_size=batch_size, verbose=1)
estimator.model = load_model('BP_saved_model.h5')    
with open('history.pickle', 'rb') as f:
    history = pickle.load(f)
print("Loaded model from disk")
# Out:
# User settings:
#
#    KMP_AFFINITY=granularity=fine,noverbose,compact,1,0
#    KMP_BLOCKTIME=0
#    KMP_DUPLICATE_LIB_OK=True
#    KMP_INIT_AT_FORK=FALSE
#    KMP_SETTINGS=1
#    KMP_WARNINGS=0
#
# Effective settings:
#
#    KMP_ABORT_DELAY=0
#    KMP_ADAPTIVE_LOCK_PROPS='1,1024'
#    KMP_ALIGN_ALLOC=64
#    KMP_ALL_THREADPRIVATE=128
#    KMP_ATOMIC_MODE=2
#    KMP_BLOCKTIME=0
#    KMP_CPUINFO_FILE: value is not defined
#    KMP_DETERMINISTIC_REDUCTION=false
#    KMP_DEVICE_THREAD_LIMIT=2147483647
#    KMP_DISP_NUM_BUFFERS=7
#    KMP_DUPLICATE_LIB_OK=true
#    KMP_ENABLE_TASK_THROTTLING=true
#    KMP_FORCE_REDUCTION: value is not defined
#    KMP_FOREIGN_THREADS_THREADPRIVATE=true
#    KMP_FORKJOIN_BARRIER='2,2'
#    KMP_FORKJOIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_GTID_MODE=3
#    KMP_HANDLE_SIGNALS=false
#    KMP_HOT_TEAMS_MAX_LEVEL=1
#    KMP_HOT_TEAMS_MODE=0
#    KMP_INIT_AT_FORK=true
#    KMP_LIBRARY=throughput
#    KMP_LOCK_KIND=queuing
#    KMP_MALLOC_POOL_INCR=1M
#    KMP_NUM_LOCKS_IN_BLOCK=1
#    KMP_PLAIN_BARRIER='2,2'
#    KMP_PLAIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_REDUCTION_BARRIER='1,1'
#    KMP_REDUCTION_BARRIER_PATTERN='hyper,hyper'
#    KMP_SCHEDULE='static,balanced;guided,iterative'
#    KMP_SETTINGS=true
#    KMP_SPIN_BACKOFF_PARAMS='4096,100'
#    KMP_STACKOFFSET=64
#    KMP_STACKPAD=0
#    KMP_STACKSIZE=8M
#    KMP_STORAGE_MAP=false
#    KMP_TASKING=2
#    KMP_TASKLOOP_MIN_TASKS=0
#    KMP_TASK_STEALING_CONSTRAINT=1
#    KMP_TEAMS_THREAD_LIMIT=4
#    KMP_TOPOLOGY_METHOD=all
#    KMP_USE_YIELD=1
#    KMP_VERSION=false
#    KMP_WARNINGS=false
#    OMP_AFFINITY_FORMAT='OMP: pid %P tid %i thread %n bound to OS proc set {%A}'
#    OMP_ALLOCATOR=omp_default_mem_alloc
#    OMP_CANCELLATION=false
#    OMP_DEFAULT_DEVICE=0
#    OMP_DISPLAY_AFFINITY=false
#    OMP_DISPLAY_ENV=false
#    OMP_DYNAMIC=false
#    OMP_MAX_ACTIVE_LEVELS=1
#    OMP_MAX_TASK_PRIORITY=0
#    OMP_NESTED: deprecated; max-active-levels-var=1
#    OMP_NUM_THREADS: value is not defined
#    OMP_PLACES: value is not defined
#    OMP_PROC_BIND='intel'
#    OMP_SCHEDULE='static'
#    OMP_STACKSIZE=8M
#    OMP_TARGET_OFFLOAD=DEFAULT
#    OMP_THREAD_LIMIT=2147483647
#    OMP_WAIT_POLICY=PASSIVE
#    KMP_AFFINITY='noverbose,warnings,respect,granularity=fine,compact,1,0'
#
# 2022-02-22 03:26:53.550971: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2022-02-22 03:26:53.714174: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/1000
# 11/11 [==============================] - 1s 21ms/step - loss: 0.0253 - val_loss: 0.0159
# Epoch 2/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0072 - val_loss: 0.0112
# Epoch 3/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 0.0104
# Epoch 4/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0088
# Epoch 5/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.0085
# Epoch 6/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 0.0082
# Epoch 7/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0079
# Epoch 8/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0076
# Epoch 9/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0073
# Epoch 10/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0072
# Epoch 11/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0069
# Epoch 12/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 9.0866e-04 - val_loss: 0.0068
# Epoch 13/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 0.0066
# Epoch 14/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 0.0065
# Epoch 15/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 0.0066
# Epoch 16/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 8.0770e-04 - val_loss: 0.0065
# Epoch 17/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 0.0064
# Epoch 18/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 8.
1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.9246e-04 - val_loss: 0.0072
# Epoch 422/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.0991e-04 - val_loss: 0.0069
# Epoch 423/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 4.1583e-04 - val_loss: 0.0071
# Epoch 424/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 5.0851e-04 - val_loss: 0.0070
# Epoch 425/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 5.7430e-04 - val_loss: 0.0070
# Epoch 426/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 4.1777e-04 - val_loss: 0.0073
# Epoch 427/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 4.0148e-04 - val_loss: 0.0071
# Epoch 428/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.9582e-04 - val_loss: 0.0074
# Epoch 429/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.4794e-04 - val_loss: 0.0072
# Epoch 430/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 4.1738e-04 - val_loss: 0.0074
# Epoch 431/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 3.0896e-04 - val_loss: 0.0072
# Epoch 432/1000
# ...
# Epoch 851/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.3531e-04 - val_loss: 0.0076
# Epoch 852/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.8609e-04 - val_loss: 0.0077
# Epoch 853/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.9453e-04 - val_loss: 0.0078
# Epoch 854/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.2254e-04 - val_loss: 0.0078
# Epoch 855/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.7001e-04 - val_loss: 0.0082
# Epoch 856/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.5914e-04 - val_loss: 0.0076
# Epoch 857/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.8250e-04 - val_loss: 0.0085
# Epoch 858/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.6891e-04 - val_loss: 0.0080
# Epoch 859/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.8503e-04 - val_loss: 0.0076
# Epoch 860/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.3097e-04 - val_loss: 0.0078
# Epoch 861/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.0534e-04 - val_loss: 0.0077
# Epoch 862/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.6371e-04 - val_loss: 0.0077
# Epoch 863/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.4937e-04 - val_loss: 0.0079
# Epoch 864/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.8046e-04 - val_loss: 0.0077
# Epoch 865/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.5912e-04 - val_loss: 0.0081
# Epoch 866/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.4160e-04 - val_loss: 0.0077
# Epoch 867/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.0954e-04 - val_loss: 0.0076
# Epoch 868/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0010 - val_loss: 0.0081
# Epoch 869/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 7.4698e-04 - val_loss: 0.0078
# Epoch 870/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.1082e-04 - val_loss: 0.0079
# Epoch 871/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.0104e-04 - val_loss: 0.0077
# Epoch 872/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.4172e-04 - val_loss: 0.0076
# Epoch 873/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.0224e-04 - val_loss: 0.0083
# Epoch 874/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.8311e-04 - val_loss: 0.0077
# Epoch 875/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.8605e-04 - val_loss: 0.0080
# Epoch 876/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.0623e-04 - val_loss: 0.0078
# Epoch 877/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.2964e-04 - val_loss: 0.0079
# Epoch 878/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.0719e-04 - val_loss: 0.0079
# Epoch 879/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.7330e-04 - val_loss: 0.0075
# Epoch 880/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.8772e-04 - val_loss: 0.0078
# Epoch 881/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.2138e-04 - val_loss: 0.0078
# Epoch 882/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 2.4717e-04 - val_loss: 0.0079
# Epoch 883/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.2129e-04 - val_loss: 0.0076
# Epoch 884/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.4629e-04 - val_loss: 0.0079
# Epoch 885/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.9920e-04 - val_loss: 0.0078
# Epoch 886/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.3373e-04 - val_loss: 0.0080
# Epoch 887/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.4321e-04 - val_loss: 0.0079
# Epoch 888/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.0145e-04 - val_loss: 0.0078
# Epoch 889/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.0079e-04 - val_loss: 0.0080
# Epoch 890/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.8679e-04 - val_loss: 0.0082
# Epoch 891/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.3995e-04 - val_loss: 0.0078
# Epoch 892/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.0916e-04 - val_loss: 0.0082
# Epoch 893/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.7042e-04 - val_loss: 0.0079
# Epoch 894/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.2816e-04 - val_loss: 0.0079
# Epoch 895/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.8190e-04 - val_loss: 0.0082
# Epoch 896/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.7560e-04 - val_loss: 0.0079
# Epoch 897/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.2132e-04 - val_loss: 0.0091
# Epoch 898/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.7124e-04 - val_loss: 0.0082
# Epoch 899/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0079
# Epoch 900/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0010 - val_loss: 0.0083
# Epoch 901/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 8.8747e-04 - val_loss: 0.0076
# Epoch 902/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.4179e-04 - val_loss: 0.0083
# Epoch 903/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.8325e-04 - val_loss: 0.0082
# Epoch 904/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.3768e-04 - val_loss: 0.0079
# Epoch 905/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.6405e-04 - val_loss: 0.0087
# Epoch 906/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.6338e-04 - val_loss: 0.0078
# Epoch 907/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.6203e-04 - val_loss: 0.0079
# Epoch 908/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.9105e-04 - val_loss: 0.0077
# Epoch 909/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.7528e-04 - val_loss: 0.0081
# Epoch 910/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.2928e-04 - val_loss: 0.0083
# Epoch 911/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.1577e-04 - val_loss: 0.0081
# Epoch 912/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.0657e-04 - val_loss: 0.0078
# Epoch 913/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.4925e-04 - val_loss: 0.0081
# Epoch 914/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.9216e-04 - val_loss: 0.0080
# Epoch 915/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.6728e-04 - val_loss: 0.0083
# Epoch 916/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.7921e-04 - val_loss: 0.0078
# Epoch 917/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.1740e-04 - val_loss: 0.0083
# Epoch 918/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.6550e-04 - val_loss: 0.0078
# Epoch 919/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.0513e-04 - val_loss: 0.0079
# Epoch 920/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.6663e-04 - val_loss: 0.0081
# Epoch 921/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.3017e-04 - val_loss: 0.0078
# Epoch 922/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.3073e-04 - val_loss: 0.0078
# Epoch 923/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.0159e-04 - val_loss: 0.0084
# Epoch 924/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.6881e-04 - val_loss: 0.0078
# Epoch 925/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 2.8858e-04 - val_loss: 0.0081
# Epoch 926/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.9569e-04 - val_loss: 0.0077
# Epoch 927/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.9179e-04 - val_loss: 0.0076
# Epoch 928/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.6784e-04 - val_loss: 0.0076
# Epoch 929/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.0248e-04 - val_loss: 0.0082
# Epoch 930/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.1442e-04 - val_loss: 0.0079
# Epoch 931/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.4803e-04 - val_loss: 0.0078
# Epoch 932/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.5438e-04 - val_loss: 0.0083
# Epoch 933/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.2626e-04 - val_loss: 0.0077
# Epoch 934/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.2795e-04 - val_loss: 0.0079
# Epoch 935/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.4024e-04 - val_loss: 0.0080
# Epoch 936/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.6873e-04 - val_loss: 0.0074
# Epoch 937/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 0.0072
# Epoch 938/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0084
# Epoch 939/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.2565e-04 - val_loss: 0.0078
# Epoch 940/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.7466e-04 - val_loss: 0.0078
# Epoch 941/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.0626e-04 - val_loss: 0.0078
# Epoch 942/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.9556e-04 - val_loss: 0.0075
# Epoch 943/1000
# 11/11 [==============================] - 0s 12ms/step - loss: 5.1984e-04 - val_loss: 0.0079
# Epoch 944/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.0085e-04 - val_loss: 0.0080
# Epoch 945/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.3575e-04 - val_loss: 0.0078
# Epoch 946/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.5435e-04 - val_loss: 0.0076
# Epoch 947/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.2270e-04 - val_loss: 0.0080
# Epoch 948/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.9231e-04 - val_loss: 0.0079
# Epoch 949/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.6291e-04 - val_loss: 0.0086
# Epoch 950/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.1437e-04 - val_loss: 0.0082
# Epoch 951/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.3413e-04 - val_loss: 0.0085
# Epoch 952/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.2095e-04 - val_loss: 0.0081
# Epoch 953/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.3975e-04 - val_loss: 0.0077
# Epoch 954/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.9363e-04 - val_loss: 0.0081
# Epoch 955/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.2548e-04 - val_loss: 0.0081
# Epoch 956/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.9066e-04 - val_loss: 0.0083
# Epoch 957/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.2858e-04 - val_loss: 0.0083
# Epoch 958/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.7208e-04 - val_loss: 0.0080
# Epoch 959/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.1042e-04 - val_loss: 0.0081
# Epoch 960/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.9830e-04 - val_loss: 0.0085
# Epoch 961/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.1943e-04 - val_loss: 0.0081
# Epoch 962/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.5685e-04 - val_loss: 0.0080
# Epoch 963/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.4695e-04 - val_loss: 0.0079
# Epoch 964/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.6880e-04 - val_loss: 0.0080
# Epoch 965/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.1620e-04 - val_loss: 0.0080
# Epoch 966/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.4405e-04 - val_loss: 0.0082
# Epoch 967/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.6593e-04 - val_loss: 0.0082
# Epoch 968/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.2790e-04 - val_loss: 0.0080
# Epoch 969/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.1001e-04 - val_loss: 0.0081
# Epoch 970/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.5887e-04 - val_loss: 0.0085
# Epoch 971/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.1267e-04 - val_loss: 0.0080
# Epoch 972/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.2695e-04 - val_loss: 0.0082
# Epoch 973/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.9871e-04 - val_loss: 0.0080
# Epoch 974/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.2466e-04 - val_loss: 0.0079
# Epoch 975/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.5032e-04 - val_loss: 0.0080
# Epoch 976/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.1063e-04 - val_loss: 0.0077
# Epoch 977/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.7113e-04 - val_loss: 0.0084
# Epoch 978/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.0423e-04 - val_loss: 0.0076
# Epoch 979/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.4068e-04 - val_loss: 0.0083
# Epoch 980/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.7799e-04 - val_loss: 0.0082
# Epoch 981/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.6192e-04 - val_loss: 0.0082
# Epoch 982/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.9589e-04 - val_loss: 0.0083
# Epoch 983/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.3357e-04 - val_loss: 0.0080
# Epoch 984/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.0668e-04 - val_loss: 0.0081
# Epoch 985/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.3198e-04 - val_loss: 0.0084
# Epoch 986/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.9411e-04 - val_loss: 0.0081
# Epoch 987/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.1412e-04 - val_loss: 0.0081
# Epoch 988/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.9410e-04 - val_loss: 0.0095
# Epoch 989/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0085
# Epoch 990/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0086
# Epoch 991/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.6625e-04 - val_loss: 0.0077
# Epoch 992/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.6845e-04 - val_loss: 0.0081
# Epoch 993/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.1574e-04 - val_loss: 0.0082
# Epoch 994/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.9232e-04 - val_loss: 0.0077
# Epoch 995/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.4280e-04 - val_loss: 0.0080
# Epoch 996/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.8153e-04 - val_loss: 0.0078
# Epoch 997/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.0742e-04 - val_loss: 0.0081
# Epoch 998/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.7440e-04 - val_loss: 0.0078
# Epoch 999/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 4.6567e-04 - val_loss: 0.0079
# Epoch 1000/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.4686e-04 - val_loss: 0.0082
# Saved model to disk
# Loaded model from disk

# %%
plt.figure()
plt.plot(history['loss'], label='train')
plt.plot(history['val_loss'], label='test')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.show()

# %% [markdown]
# As you can see, a Neural Network is well-fitted and no overfitting is observed.
# Let's calculate a prediction of the training (**res_train_ANN**) an test (**res_test_ANN**) sets.

# %% [markdown]
# Let's calculate a forecast and make an inverse normalization to real scale.

# %%
res_tr=estimator.predict(X_train)
res_ts=estimator.predict(X_test)
res_train_ANN=scaler_y.inverse_transform(res_tr.reshape(-1, 1)).flatten()
res_test_ANN=scaler_y.inverse_transform(res_ts.reshape(-1, 1)).flatten()
# Out:
# 11/11 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step

# %% [markdown]
# Let's compare the accuracy of a Linear Regression and a Neural Network.

# %%
print("Correlation train", np.corrcoef(res_train, res_train_ANN)[0,1])
print("Correlation train", np.corrcoef(res_test, res_test_ANN)[0,1])
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, res_test_ANN))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, res_test_ANN))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, res_test_ANN)))
# Out:
# Correlation train 0.9983569840968889
# Correlation train 0.8558830504978225
# Mean Absolute Error: 56309.06822407781
# Mean Squared Error: 11444552699.610567
# Root Mean Squared Error: 106979.21620394575

# %% [markdown]
# We got slightly better results for a Neural Network than for a Linear Regression.

# %% [markdown]
# # Long Short-Term Memory - LSTM

# %% [markdown]
# Unlike standard feedforward neural networks, **LSTM** has feedback connections. It can process not only single data points, but also entire sequences of data (such as speech, video or time series).
#
# In case of time series, the neural network has one input and one output. However, there should be a vector of time series values for the previous time period on the input.

# %% [markdown]
# To do this, we should transform input DataSets into 3D shape.

# %%
train_x_LSTM = X_train.reshape((X_train.shape[0], 1, 14))
test_x_LSTM = X_test.reshape((X_test.shape[0], 1, 14))

# %% [markdown]
# Let's create an LSTM Neural Network consisting of one **LSTM** layer and one BP layer like in the previous case.
# In this case our NN will consist of 7 LSTM and 7 BP neurons only.

# %%
from keras.layers import LSTM

batch_size=int(y_train.shape[0]*.1)
model = Sequential()
model.add(LSTM(7, input_shape=(train_x_LSTM.shape[1], train_x_LSTM.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(7, kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(y_train.shape[1])) #activation='sigmoid'
model.compile(loss='mean_squared_error', optimizer='adam')

# %% [markdown]
# All subsequent steps of learning, storing, reading and predicting are similar to the ones we used with the previous neural network. You can see that only 420 epochs are enough for an LSTM.

# %%
fitting = True
fitting_save = True
epochs = 420

if fitting:
    history = model.fit(train_x_LSTM, y_train, epochs=epochs, batch_size=batch_size, validation_data=(test_x_LSTM, y_test), verbose=1, shuffle=False)    
    if fitting_save:
    # serialize model to JSON
        model_json = model.to_json()
        with open("LSTM_model.json", "w") as json_file:
            json_file.write(model_json)
        # serialize weights to HDF5
        model.save_weights("LSTM_model.h5")
        print("Saved model to disk")
        with open('history_LSTM.pickle', 'wb') as f:
            pickle.dump(history.history, f)
# load model  
from keras.models import model_from_json
json_file = open('LSTM_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
model = model_from_json(loaded_model_json)
# load weights into new model
model.load_weights("LSTM_model.h5")        
with open('history_LSTM.pickle', 'rb') as f:
    history = pickle.load(f)
print("Loaded model from disk")
# Out:
# Epoch 1/420
# 11/11 [==============================] - 3s 54ms/step - loss: 0.0359 - val_loss: 0.0340
# Epoch 2/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0327 - val_loss: 0.0317
# Epoch 3/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0300 - val_loss: 0.0298
# Epoch 4/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0282 - val_loss: 0.0284
# Epoch 5/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0267 - val_loss: 0.0273
# Epoch 6/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0251 - val_loss: 0.0264
# Epoch 7/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0247 - val_loss: 0.0257
# Epoch 8/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0238 - val_loss: 0.0250
# Epoch 9/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0226 - val_loss: 0.0244
# Epoch 10/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0223 - val_loss: 0.0237
# Epoch 11/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0213 - val_loss: 0.0231
# Epoch 12/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.
420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 0.0062
# Epoch 324/420
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0029 - val_loss: 0.0062
# Epoch 325/420
# 11/11 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0063
# Epoch 326/420
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0030 - val_loss: 0.0063
# Epoch 327/420
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0031 - val_loss: 0.0063
# Epoch 328/420
# 11/11 [==============================] - 0s 13ms/step - loss: 0.0035 - val_loss: 0.0063
# Epoch 329/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0028 - val_loss: 0.0063
# Epoch 330/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0063
# Epoch 331/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0063
# Epoch 332/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0030 - val_loss: 0.0063
# Epoch 333/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0037 - val_loss: 0.0063
# Epoch 334/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0037 - val_loss: 0.0063
# Epoch 335/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0063
# Epoch 336/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0033 - val_loss: 0.0063
# Epoch 337/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0063
# Epoch 338/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0064
# Epoch 339/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.0063
# Epoch 340/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0030 - val_loss: 0.0063
# Epoch 341/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0035 - val_loss: 0.0063
# Epoch 342/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 0.0063
# Epoch 343/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0048 - val_loss: 0.0063
# Epoch 344/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 0.0063
# Epoch 345/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.0063
# Epoch 346/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0030 - val_loss: 0.0063
# Epoch 347/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0035 - val_loss: 0.0062
# Epoch 348/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 0.0062
# Epoch 349/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0033 - val_loss: 0.0063
# Epoch 350/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0063
# Epoch 351/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0063
# Epoch 352/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0063
# Epoch 353/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 0.0063
# Epoch 354/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 0.0063
# Epoch 355/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 0.0064
# Epoch 356/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0031 - val_loss: 0.0063
# Epoch 357/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 0.0063
# Epoch 358/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0030 - val_loss: 0.0063
# Epoch 359/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 0.0063
# Epoch 360/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0063
# Epoch 361/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0063
# Epoch 362/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 0.0063
# Epoch 363/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.0063
# Epoch 364/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0036 - val_loss: 0.0063
# Epoch 365/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 0.0063
# Epoch 366/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0030 - val_loss: 0.0063
# Epoch 367/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0063
# Epoch 368/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0063
# Epoch 369/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0063
# Epoch 370/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0034 - val_loss: 0.0063
# Epoch 371/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0030 - val_loss: 0.0062
# Epoch 372/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0063
# Epoch 373/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0063
# Epoch 374/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0033 - val_loss: 0.0063
# Epoch 375/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.0062
# Epoch 376/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0037 - val_loss: 0.0062
# Epoch 377/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0037 - val_loss: 0.0063
# Epoch 378/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0063
# Epoch 379/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.0063
# Epoch 380/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.0063
# Epoch 381/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0063
# Epoch 382/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.0063
# Epoch 383/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0063
# Epoch 384/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0041 - val_loss: 0.0063
# Epoch 385/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0038 - val_loss: 0.0063
# Epoch 386/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0039 - val_loss: 0.0063
# Epoch 387/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0032 - val_loss: 0.0063
# Epoch 388/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0032 - val_loss: 0.0064
# Epoch 389/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 0.0063
# Epoch 390/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0030 - val_loss: 0.0062
# Epoch 391/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0030 - val_loss: 0.0063
# Epoch 392/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0062
# Epoch 393/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0033 - val_loss: 0.0062
# Epoch 394/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0033 - val_loss: 0.0063
# Epoch 395/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0037 - val_loss: 0.0063
# Epoch 396/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0063
# Epoch 397/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 0.0064
# Epoch 398/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0039 - val_loss: 0.0064
# Epoch 399/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0036 - val_loss: 0.0063
# Epoch 400/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0030 - val_loss: 0.0062
# Epoch 401/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0041 - val_loss: 0.0063
# Epoch 402/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 0.0063
# Epoch 403/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0030 - val_loss: 0.0063
# Epoch 404/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0040 - val_loss: 0.0062
# Epoch 405/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0039 - val_loss: 0.0063
# Epoch 406/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0038 - val_loss: 0.0063
# Epoch 407/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0063
# Epoch 408/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 0.0062
# Epoch 409/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 0.0062
# Epoch 410/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0063
# Epoch 411/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0063
# Epoch 412/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.0063
# Epoch 413/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0063
# Epoch 414/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0033 - val_loss: 0.0063
# Epoch 415/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0063
# Epoch 416/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0063
# Epoch 417/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0063
# Epoch 418/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0063
# Epoch 419/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.0063
# Epoch 420/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0031 - val_loss: 0.0063
# Saved model to disk
# Loaded model from disk

# %% [markdown]
# Let's plot the dynamic of loss and val loss like in the previous case.

# %%
plt.figure()
plt.plot(history['loss'], label='train')
plt.plot(history['val_loss'], label='test')
plt.ylabel('loss')
plt.xlabel('epoch')

plt.legend()
plt.show()

# %% [markdown]
# Let's calculate our forecast.

# %%
res_tr_LSTM = model.predict(train_x_LSTM)
res_ts_LSTM = model.predict(test_x_LSTM)
res_train_LSTM=scaler_y.inverse_transform(res_tr_LSTM).flatten()
res_test_LSTM=scaler_y.inverse_transform(res_ts_LSTM).flatten()

# %% [markdown]
# And accuracy:

# %%
print("Correlation train", np.corrcoef(res_train, res_train_LSTM)[0,1])
print("Correlation train", np.corrcoef(res_test, res_test_LSTM)[0,1])
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, res_test_LSTM))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, res_test_LSTM))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, res_test_LSTM)))
# Out:
# Correlation train 0.9958927141249594
# Correlation train 0.8770323911865763
# Mean Absolute Error: 53357.70620631847
# Mean Squared Error: 8669853422.407211
# Root Mean Squared Error: 93112.04767594369

# %% [markdown]
# As you can see, the forecast results of the test data set are much better than ones of the previous models. Let's visualize these 3 results:

# %%
res_pred_test_ln = pd.Series(y_pred_test_ln, name = 'Predicted test Linear Model')
res_pred_test_ANN = pd.Series(res_test_ANN, name = 'Predicted test ANN')
res_pred_test_LSTM = pd.Series(res_test_LSTM, name = 'Predicted test LSTM')

df_2 = pd.DataFrame({'Actual test': res_test, 'Linear Model': res_pred_test_ln, 'ANN Model': res_pred_test_ANN,  'LSTM Model': res_pred_test_LSTM,})
df_2.index = dataset.index[len(dataset)-len(res_test):]
df_2.plot()
df_2 = pd.DataFrame({'Actual test': res_test, 'Linear Model': res_pred_test_ln,})
df_2.index = dataset.index[len(dataset)-len(res_test):]
df_2.plot()
df_2 = pd.DataFrame({'Actual test': res_test, 'LSTM Model': res_pred_test_LSTM,})
df_2.index = dataset.index[len(dataset)-len(res_test):]
df_2.plot()
df_2 = pd.DataFrame({'Actual test': res_test,'ANN Model': res_pred_test_ANN,})
df_2.index = dataset.index[len(dataset)-len(res_test):]
df_2.plot()
plt.show()

# %% [markdown]
# As you can see, an LSTM model makes a perfect forecast. A Linear Regression is the fastest forecasting model.
