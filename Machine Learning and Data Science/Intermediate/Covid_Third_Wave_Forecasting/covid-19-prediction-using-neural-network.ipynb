# %% [markdown]
# <a href="https://www.kaggle.com/shiv28/covid-19-prediction-using-neural-network?scriptVersionId=89158432" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ## **Covid-19 prediction using Neural Network**

# %% [markdown]
# ## Abstract

# %% [markdown]
# This notebook is devoted to predicting the COVID-19 spread dynamics in the world using neural networks of different structures. We will see how to make predictions based on linear regression, back propagation  and long short-term memory neural networks

# %% [markdown]
# ## Introduction

# %% [markdown]
# Today there is a lot of open data about the spread of COVID-19 in the world. However, few tools are presented to predict  these processes.
#
# 3 different mathematical models for the forecast calculation will taken.
#
# To do this, the division of the DataSet into training and test sets will be demonstrated, normalize data and make preliminary analysis.
#
# It will be shown how to build models and DataSets for using 2 different neural networks.
#
# The next step is to compare the accuracy and adequacy of the obtained models.

# %% [markdown]
# ## Steps or Stages

# %% [markdown]
# It consists of four stages:
#
# *   Download and preliminary analysis of data
# *   Linear Regression
# *   Back Propagation NN
# *   Long Short-Term Memory - LSTM

# %% [markdown]
# In first stage we pre-prepare data for analysis:
#
# *   change the data types of columns
# *   rows filtering
# *   elimination of missing data
# *   DataSet transformation
# *   data normalization
#
# During the next steps, we will demonstrate 3 different models .

# %% [markdown]
# ## Prerequisites
#
# *   Python
# *   Pandas
# *   Statistics
# *   NumPy
# *   Matplotlib
# *   Keras
# *   Scikit-Learn

# %% [markdown]
# ## Objectives

# %% [markdown]
# ## Required libraries Importing

# %% [markdown]
# Some libraries should be imported .

# %%
import pandas as pd
import numpy as np

# %%
covid_word = pd.read_csv('../input/covidowid/owid-covid-data (1).csv')
covid_word
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 165403      ZWE    Africa     Zimbabwe  2022-02-25     235467.0      500.0
# 165404      ZWE    Africa     Zimbabwe  2022-02-26     235803.0      336.0
# 165405      ZWE    Africa     Zimbabwe  2022-02-27     235803.0        0.0
# 165406      ZWE    Africa     Zimbabwe  2022-02-28     236380.0      577.0
# 165407      ZWE    Africa     Zimbabwe  2022-03-01     236871.0      491.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         NaN                  NaN
# 1                      NaN           NaN         NaN                  NaN
# 2                      NaN           NaN         NaN                  NaN
# 3                      NaN           NaN         NaN                  NaN
# 4                      NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 165403             348.143        5392.0         2.0                1.000
# 165404             368.429        5393.0         1.0                1.000
# 165405             350.143        5393.0         0.0                1.000
# 165406             401.286        5395.0         2.0                1.286
# 165407             413.000        5395.0         0.0                1.000
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 0       ...             NaN           NaN                  37.746
# 1       ...             NaN           NaN                  37.746
# 2       ...             NaN           NaN                  37.746
# 3       ...             NaN           NaN                  37.746
# 4       ...             NaN           NaN                  37.746
# ...     ...             ...           ...                     ...
# 165403  ...             1.6          30.7                  36.791
# 165404  ...             1.6          30.7                  36.791
# 165405  ...             1.6          30.7                  36.791
# 165406  ...             1.6          30.7                  36.791
# 165407  ...             1.6          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                              0.5            64.83                    0.511
# 1                              0.5            64.83                    0.511
# 2                              0.5            64.83                    0.511
# 3                              0.5            64.83                    0.511
# 4                              0.5            64.83                    0.511
# ...                            ...              ...                      ...
# 165403                         1.7            61.49                    0.571
# 165404                         1.7            61.49                    0.571
# 165405                         1.7            61.49                    0.571
# 165406                         1.7            61.49                    0.571
# 165407                         1.7            61.49                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 165403                                   NaN                          NaN
# 165404                                   NaN                          NaN
# 165405                                   NaN                          NaN
# 165406                                   NaN                          NaN
# 165407                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 165403               NaN                                      NaN
# 165404               NaN                                      NaN
# 165405               NaN                                      NaN
# 165406               NaN                                      NaN
# 165407               NaN                                      NaN
#
# [165408 rows x 67 columns]

# %% [markdown]
# Let's study our DataSet. As you can see, it consist of 159321 rows × 67 columns. There is some missing data are observed in the DataSet. We should be sure that Python recognized types of data correctly.

# %%
covid_word.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165408 entries, 0 to 165407
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    165408 non-null  object
#  1   continent                                   155504 non-null  object
#  2   location                                    165408 non-null  object
#  3   date                                        165408 non-null  object
#  4   total_cases                                 162378 non-null  float64
#  5   new_cases                                   162230 non-null  float64
#  6   new_cases_smoothed                          160247 non-null  float64
#  7   total_deaths                                144574 non-null  float64
#  8   new_deaths                                  144611 non-null  float64
#  9   new_deaths_smoothed                         142515 non-null  float64
#  10  total_cases_per_million                     161624 non-null  float64
#  11  new_cases_per_million                       161476 non-null  float64
#  12  new_cases_smoothed_per_million              159499 non-null  float64
#  13  total_deaths_per_million                    143833 non-null  float64
#  14  new_deaths_per_million                      143870 non-null  float64
#  15  new_deaths_smoothed_per_million             141780 non-null  float64
#  16  reproduction_rate                           125067 non-null  float64
#  17  icu_patients                                23307 non-null   float64
#  18  icu_patients_per_million                    23307 non-null   float64
#  19  hosp_patients                               24450 non-null   float64
#  20  hosp_patients_per_million                   24450 non-null   float64
#  21  weekly_icu_admissions                       5394 non-null    float64
#  22  weekly_icu_admissions_per_million           5394 non-null    float64
#  23  weekly_hosp_admissions                      10858 non-null   float64
#  24  weekly_hosp_admissions_per_million          10858 non-null   float64
#  25  new_tests                                   67006 non-null   float64
#  26  total_tests                                 68944 non-null   float64
#  27  total_tests_per_thousand                    68944 non-null   float64
#  28  new_tests_per_thousand                      67006 non-null   float64
#  29  new_tests_smoothed                          83658 non-null   float64
#  30  new_tests_smoothed_per_thousand             83658 non-null   float64
#  31  positive_rate                               78590 non-null   float64
#  32  tests_per_case                              78027 non-null   float64
#  33  tests_units                                 85981 non-null   object
#  34  total_vaccinations                          44858 non-null   float64
#  35  people_vaccinated                           42688 non-null   float64
#  36  people_fully_vaccinated                     40047 non-null   float64
#  37  total_boosters                              17241 non-null   float64
#  38  new_vaccinations                            37155 non-null   float64
#  39  new_vaccinations_smoothed                   83919 non-null   float64
#  40  total_vaccinations_per_hundred              44858 non-null   float64
#  41  people_vaccinated_per_hundred               42688 non-null   float64
#  42  people_fully_vaccinated_per_hundred         40047 non-null   float64
#  43  total_boosters_per_hundred                  17241 non-null   float64
#  44  new_vaccinations_smoothed_per_million       83919 non-null   float64
#  45  new_people_vaccinated_smoothed              82654 non-null   float64
#  46  new_people_vaccinated_smoothed_per_hundred  82654 non-null   float64
#  47  stringency_index                            129843 non-null  float64
#  48  population                                  164337 non-null  float64
#  49  population_density                          147109 non-null  float64
#  50  median_age                                  137068 non-null  float64
#  51  aged_65_older                               135582 non-null  float64
#  52  aged_70_older                               136333 non-null  float64
#  53  gdp_per_capita                              137737 non-null  float64
#  54  extreme_poverty                             90712 non-null   float64
#  55  cardiovasc_death_rate                       136019 non-null  float64
#  56  diabetes_prevalence                         143150 non-null  float64
#  57  female_smokers                              105463 non-null  float64
#  58  male_smokers                                104016 non-null  float64
#  59  handwashing_facilities                      68189 non-null   float64
#  60  hospital_beds_per_thousand                  122981 non-null  float64
#  61  life_expectancy                             154405 non-null  float64
#  62  human_development_index                     135494 non-null  float64
#  63  excess_mortality_cumulative_absolute        5696 non-null    float64
#  64  excess_mortality_cumulative                 5696 non-null    float64
#  65  excess_mortality                            5696 non-null    float64
#  66  excess_mortality_cumulative_per_million     5696 non-null    float64
# dtypes: float64(62), object(5)
# memory usage: 84.6+ MB

# %% [markdown]
# As you can see, 66 columns of COVID-19 data were recognized correctly (float64). First 4 columns and tests_units were recognized as objects. Let's investigate them:

# %%
fields = ['iso_code', 'continent', 'location', 'tests_units']
covid_word[fields]
# Out:
#        iso_code continent     location      tests_units
# 0           AFG      Asia  Afghanistan              NaN
# 1           AFG      Asia  Afghanistan              NaN
# 2           AFG      Asia  Afghanistan              NaN
# 3           AFG      Asia  Afghanistan              NaN
# 4           AFG      Asia  Afghanistan              NaN
# ...         ...       ...          ...              ...
# 165403      ZWE    Africa     Zimbabwe  tests performed
# 165404      ZWE    Africa     Zimbabwe  tests performed
# 165405      ZWE    Africa     Zimbabwe  tests performed
# 165406      ZWE    Africa     Zimbabwe              NaN
# 165407      ZWE    Africa     Zimbabwe              NaN
#
# [165408 rows x 4 columns]

# %% [markdown]
# Let's show information about the field date.

# %%
covid_word['date']
# Out:
# 0         2020-02-24
# 1         2020-02-25
# 2         2020-02-26
# 3         2020-02-27
# 4         2020-02-28
#              ...
# 165403    2022-02-25
# 165404    2022-02-26
# 165405    2022-02-27
# 165406    2022-02-28
# 165407    2022-03-01
# Name: date, Length: 165408, dtype: object

# %% [markdown]
# ### Сhange the data types of columns

# %% [markdown]
# As you can see, the columns: 'iso_code', 'continent', 'location', 'tests_units' have many repetitions and should be assigned to categorical fields **pandas.astype()**.
#
# The field 'data' should be converted into DataTime type **pandas.to_datetime**
# To see the results we can use **pandas.describe()**.

# %%
fields = ['iso_code', 'continent', 'location', 'tests_units']
covid_word[fields] =covid_word[fields].astype('category')
covid_word.loc[:, 'date'] = pd.to_datetime(covid_word['date'])
covid_word[fields].describe()
# Out:
#        iso_code continent   location      tests_units
# count    165408    155504     165408            85981
# unique      238         6        238                4
# top         ARG    Africa  Argentina  tests performed
# freq        791     39197        791            62269

# %% [markdown]
# ### Rows filtering

# %% [markdown]
# As we can see, the DataSet contains information about 6 continents and 238 countries.
# The field 'tests_units' consist of 4 categories. To show a list of countries, we can use **pandas.Series.cat.categories**.

# %%
covid_word['location'].cat.categories
# Out:
# Index(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia',
#        ...
#        'Uzbekistan', 'Vanuatu', 'Vatican', 'Venezuela', 'Vietnam',
#        'Wallis and Futuna', 'World', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', length=238)

# %% [markdown]
# Let's investigate the dynamics of new cases of COVID-19 for a separate country. We will use India for saving models and further forecast. You can use your country. Let's use a pandas filter to do this.

# %%
covid_word.index = covid_word['date']
c_covid = covid_word[covid_word['location'] == "India"]
c_covid
# Out:
#            iso_code continent location       date  total_cases  new_cases  \
# date
# 2020-01-30      IND      Asia    India 2020-01-30          1.0        1.0
# 2020-01-31      IND      Asia    India 2020-01-31          1.0        0.0
# 2020-02-01      IND      Asia    India 2020-02-01          1.0        0.0
# 2020-02-02      IND      Asia    India 2020-02-02          2.0        1.0
# 2020-02-03      IND      Asia    India 2020-02-03          3.0        1.0
# ...             ...       ...      ...        ...          ...        ...
# 2022-02-25      IND      Asia    India 2022-02-25   42905844.0    11499.0
# 2022-02-26      IND      Asia    India 2022-02-26   42916117.0    10273.0
# 2022-02-27      IND      Asia    India 2022-02-27   42924130.0     8013.0
# 2022-02-28      IND      Asia    India 2022-02-28   42931045.0     6915.0
# 2022-03-01      IND      Asia    India 2022-03-01   42938599.0     7554.0
#
#             new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# date
# 2020-01-30                 NaN           NaN         NaN                  NaN
# 2020-01-31                 NaN           NaN         NaN                  NaN
# 2020-02-01                 NaN           NaN         NaN                  NaN
# 2020-02-02                 NaN           NaN         NaN                  NaN
# 2020-02-03                 NaN           NaN         NaN                  NaN
# ...                        ...           ...         ...                  ...
# 2022-02-25           14762.714      513481.0       255.0              321.571
# 2022-02-26           13377.714      513724.0       243.0              260.143
# 2022-02-27           12229.429      513843.0       119.0              247.714
# 2022-02-28           11302.286      514023.0       180.0              239.857
# 2022-03-01           10224.000      514246.0       223.0              232.000
#
#             ...  female_smokers  male_smokers  handwashing_facilities  \
# date        ...
# 2020-01-30  ...             1.9          20.6                   59.55
# 2020-01-31  ...             1.9          20.6                   59.55
# 2020-02-01  ...             1.9          20.6                   59.55
# 2020-02-02  ...             1.9          20.6                   59.55
# 2020-02-03  ...             1.9          20.6                   59.55
# ...         ...             ...           ...                     ...
# 2022-02-25  ...             1.9          20.6                   59.55
# 2022-02-26  ...             1.9          20.6                   59.55
# 2022-02-27  ...             1.9          20.6                   59.55
# 2022-02-28  ...             1.9          20.6                   59.55
# 2022-03-01  ...             1.9          20.6                   59.55
#
#             hospital_beds_per_thousand  life_expectancy  \
# date
# 2020-01-30                        0.53            69.66
# 2020-01-31                        0.53            69.66
# 2020-02-01                        0.53            69.66
# 2020-02-02                        0.53            69.66
# 2020-02-03                        0.53            69.66
# ...                                ...              ...
# 2022-02-25                        0.53            69.66
# 2022-02-26                        0.53            69.66
# 2022-02-27                        0.53            69.66
# 2022-02-28                        0.53            69.66
# 2022-03-01                        0.53            69.66
#
#             human_development_index  excess_mortality_cumulative_absolute  \
# date
# 2020-01-30                    0.645                                   NaN
# 2020-01-31                    0.645                                   NaN
# 2020-02-01                    0.645                                   NaN
# 2020-02-02                    0.645                                   NaN
# 2020-02-03                    0.645                                   NaN
# ...                             ...                                   ...
# 2022-02-25                    0.645                                   NaN
# 2022-02-26                    0.645                                   NaN
# 2022-02-27                    0.645                                   NaN
# 2022-02-28                    0.645                                   NaN
# 2022-03-01                    0.645                                   NaN
#
#             excess_mortality_cumulative  excess_mortality  \
# date
# 2020-01-30                          NaN               NaN
# 2020-01-31                          NaN               NaN
# 2020-02-01                          NaN               NaN
# 2020-02-02                          NaN               NaN
# 2020-02-03                          NaN               NaN
# ...                                 ...               ...
# 2022-02-25                          NaN               NaN
# 2022-02-26                          NaN               NaN
# 2022-02-27                          NaN               NaN
# 2022-02-28                          NaN               NaN
# 2022-03-01                          NaN               NaN
#
#             excess_mortality_cumulative_per_million
# date
# 2020-01-30                                      NaN
# 2020-01-31                                      NaN
# 2020-02-01                                      NaN
# 2020-02-02                                      NaN
# 2020-02-03                                      NaN
# ...                                             ...
# 2022-02-25                                      NaN
# 2022-02-26                                      NaN
# 2022-02-27                                      NaN
# 2022-02-28                                      NaN
# 2022-03-01                                      NaN
#
# [762 rows x 67 columns]

# %% [markdown]
# Let's choose the fields 'new_cases', 'new_cases_smoothed' for forecasting. First of all, we should visualize this data.

# %%
import matplotlib.pyplot as plt
fields = ['new_cases', 'new_cases_smoothed']
c_covid[fields].plot()
plt.show()

# %% [markdown]
# ### Elimination of missing data

# %% [markdown]
# As you can see, there are large fluctuations in the new cases plot. Let's try to make a forecast for these waves.
# First of all, we should delete missing data using **pandas.DataFrame.dropna()**

# %%
c_covid = c_covid[fields].dropna()
c_covid
# Out:
#             new_cases  new_cases_smoothed
# date
# 2020-02-05        0.0               0.429
# 2020-02-06        0.0               0.286
# 2020-02-07        0.0               0.286
# 2020-02-08        0.0               0.286
# 2020-02-09        0.0               0.143
# ...               ...                 ...
# 2022-02-25    11499.0           14762.714
# 2022-02-26    10273.0           13377.714
# 2022-02-27     8013.0           12229.429
# 2022-02-28     6915.0           11302.286
# 2022-03-01     7554.0           10224.000
#
# [756 rows x 2 columns]

# %% [markdown]
# ### Data transformation

# %% [markdown]
#  To check for dependencies, it is necessary to perform a correlation analysis between them. This requires:
#
# 1.  duplicating of data and moving it vertically down for a certain number of days (lag)
# 2.  deleting the missing data at the beginning and end **pandas.DataFrame.shift()**
# 3.  calculating the correlation coefficient between the obtained series.
#
# It is convenient to create a separate function for lag:

# %%
def lag_correlation_ts(y, x, lag):
    """
   
    y: fixed
    x: shifted
    lag: lag for shifting
    r: DataFrame of lags correlation coefficients
    """
    r = [0] * (lag + 1)
    y = y.copy()
    x = x.copy()
    y.name = "y"
    x.name = "x"

    for i in range(0, lag + 1):
        ds = y.copy().to_frame()
        ds = ds.join(x.shift(i), how='outer')
        r[i] = ds.corr().values[0][1]
    r = pd.DataFrame(r)
    r.index.names = ['Lag']
    r.columns = ['Correlation']
    return r

# %% [markdown]
# Let's create a target DataSet.

# %%
y_dataset = c_covid['new_cases']
y_dataset
# Out:
# date
# 2020-02-05        0.0
# 2020-02-06        0.0
# 2020-02-07        0.0
# 2020-02-08        0.0
# 2020-02-09        0.0
#                ...
# 2022-02-25    11499.0
# 2022-02-26    10273.0
# 2022-02-27     8013.0
# 2022-02-28     6915.0
# 2022-03-01     7554.0
# Name: new_cases, Length: 756, dtype: float64

# %% [markdown]
# Let's test a 50-day lag.

# %%
pd.options.display.float_format = '{:,.4f}'.format
l = pd.DataFrame(lag_correlation_ts(y_dataset, y_dataset, 50)) 
print(l)
l.plot()
# Out:
#      Correlation
# Lag
# 0         1.0000
# 1         0.9945
# 2         0.9861
# 3         0.9774
# 4         0.9667
# 5         0.9544
# 6         0.9417
# 7         0.9259
# 8         0.9026
# 9         0.8771
# 10        0.8521
# 11        0.8265
# 12        0.8000
# 13        0.7745
# 14        0.7467
# 15        0.7136
# 16        0.6803
# 17        0.6489
# 18        0.6179
# 19        0.5874
# 20        0.5590
# 21        0.5301
# 22        0.4979
# 23        0.4666
# 24        0.4383
# 25        0.4112
# 26        0.3856
# 27        0.3624
# 28        0.3397
# 29        0.3147
# 30        0.2910
# 31        0.2703
# 32        0.2511
# 33        0.2329
# 34        0.2168
# 35        0.2014
# 36        0.1839
# 37        0.1669
# 38        0.1529
# 39        0.1399
# 40        0.1279
# 41        0.1178
# 42        0.1070
# 43        0.0935
# 44        0.0805
# 45        0.0694
# 46        0.0592
# 47        0.0495
# 48        0.0414
# 49        0.0330
# 50        0.0220
# <AxesSubplot:xlabel='Lag'>

# %% [markdown]
# To automate this process, let's make a universal function for time series transformation to create this DataSet.

# %%
def series_to_supervised(in_data, tar_data, n_in=1, dropnan=True, target_dep=False):

    n_vars = in_data.shape[1]
    cols, names = list(), list()

    if target_dep:
        i_start = 1
    else:
        i_start = 0
    for i in range(i_start, n_in + 1):
        cols.append(in_data.shift(i))
        names += [('%s(t-%d)' % (in_data.columns[j], i)) for j in range(n_vars)]

    if target_dep:
        for i in range(n_in, -1, -1):
            cols.append(tar_data.shift(i))
            names += [('%s(t-%d)' % (tar_data.name, i))]
    else:
        # put it all together
        cols.append(tar_data)
        names.append(tar_data.name)
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)

    return agg

# %% [markdown]
#  When forecasting time series, the input and output fields are the same, only shifted by the lag.

# %%
dataset = series_to_supervised(pd.DataFrame(y_dataset), y_dataset, 14)
dataset
# Out:
#             new_cases(t-0)  new_cases(t-1)  new_cases(t-2)  new_cases(t-3)  \
# date
# 2020-02-19          0.0000          0.0000          0.0000          0.0000
# 2020-02-20          0.0000          0.0000          0.0000          0.0000
# 2020-02-21          0.0000          0.0000          0.0000          0.0000
# 2020-02-22          0.0000          0.0000          0.0000          0.0000
# 2020-02-23          0.0000          0.0000          0.0000          0.0000
# ...                    ...             ...             ...             ...
# 2022-02-25     11,499.0000     13,166.0000     14,148.0000     15,102.0000
# 2022-02-26     10,273.0000     11,499.0000     13,166.0000     14,148.0000
# 2022-02-27      8,013.0000     10,273.0000     11,499.0000     13,166.0000
# 2022-02-28      6,915.0000      8,013.0000     10,273.0000     11,499.0000
# 2022-03-01      7,554.0000      6,915.0000      8,013.0000     10,273.0000
#
#             new_cases(t-4)  new_cases(t-5)  new_cases(t-6)  new_cases(t-7)  \
# date
# 2020-02-19          0.0000          0.0000          0.0000          0.0000
# 2020-02-20          0.0000          0.0000          0.0000          0.0000
# 2020-02-21          0.0000          0.0000          0.0000          0.0000
# 2020-02-22          0.0000          0.0000          0.0000          0.0000
# 2020-02-23          0.0000          0.0000          0.0000          0.0000
# ...                    ...             ...             ...             ...
# 2022-02-25     13,405.0000     16,051.0000     19,968.0000     22,270.0000
# 2022-02-26     15,102.0000     13,405.0000     16,051.0000     19,968.0000
# 2022-02-27     14,148.0000     15,102.0000     13,405.0000     16,051.0000
# 2022-02-28     13,166.0000     14,148.0000     15,102.0000     13,405.0000
# 2022-03-01     11,499.0000     13,166.0000     14,148.0000     15,102.0000
#
#             new_cases(t-8)  new_cases(t-9)  new_cases(t-10)  new_cases(t-11)  \
# date
# 2020-02-19          0.0000          0.0000           0.0000           0.0000
# 2020-02-20          0.0000          0.0000           0.0000           0.0000
# 2020-02-21          0.0000          0.0000           0.0000           0.0000
# 2020-02-22          0.0000          0.0000           0.0000           0.0000
# 2020-02-23          0.0000          0.0000           0.0000           0.0000
# ...                    ...             ...              ...              ...
# 2022-02-25     25,920.0000     30,757.0000      30,615.0000      27,409.0000
# 2022-02-26     22,270.0000     25,920.0000      30,757.0000      30,615.0000
# 2022-02-27     19,968.0000     22,270.0000      25,920.0000      30,757.0000
# 2022-02-28     16,051.0000     19,968.0000      22,270.0000      25,920.0000
# 2022-03-01     13,405.0000     16,051.0000      19,968.0000      22,270.0000
#
#             new_cases(t-12)  new_cases(t-13)  new_cases(t-14)   new_cases
# date
# 2020-02-19           0.0000           0.0000           0.0000      0.0000
# 2020-02-20           0.0000           0.0000           0.0000      0.0000
# 2020-02-21           0.0000           0.0000           0.0000      0.0000
# 2020-02-22           0.0000           0.0000           0.0000      0.0000
# 2020-02-23           0.0000           0.0000           0.0000      0.0000
# ...                     ...              ...              ...         ...
# 2022-02-25      34,113.0000      44,877.0000      50,407.0000 11,499.0000
# 2022-02-26      27,409.0000      34,113.0000      44,877.0000 10,273.0000
# 2022-02-27      30,615.0000      27,409.0000      34,113.0000  8,013.0000
# 2022-02-28      30,757.0000      30,615.0000      27,409.0000  6,915.0000
# 2022-03-01      25,920.0000      30,757.0000      30,615.0000  7,554.0000
#
# [742 rows x 16 columns]

# %% [markdown]
# As you can see, the first and last columns contain the same target data.
# Now we should create input (**X**) and output (**Y**) .

# %%
col = dataset.columns
X, Y = dataset[col[1:-1]], dataset[col[-1]]
print("Input: ", X.columns)
print("Target:", Y.name)
# Out:
# Input:  Index(['new_cases(t-1)', 'new_cases(t-2)', 'new_cases(t-3)', 'new_cases(t-4)',
#        'new_cases(t-5)', 'new_cases(t-6)', 'new_cases(t-7)', 'new_cases(t-8)',
#        'new_cases(t-9)', 'new_cases(t-10)', 'new_cases(t-11)',
#        'new_cases(t-12)', 'new_cases(t-13)', 'new_cases(t-14)'],
#       dtype='object')
# Target: new_cases

# %% [markdown]
# ### Data normalization

# %% [markdown]
# After that, we should normalize all the data. To do this, the **sklearn.preprocessing.MinMaxScaler** module should be used.
# It allows us to normalize **fit_transform()** and convert back all the data easily: **inverse_transform()**.

# %%
from sklearn.preprocessing import MinMaxScaler
scaler_x = MinMaxScaler(feature_range=(0, 1))
scaler_y = MinMaxScaler(feature_range=(0, 1))

scaled_x = scaler_x.fit_transform(X)
scaled_y = scaler_y.fit_transform(Y.values.reshape(-1, 1))

# %% [markdown]
# After that, we are going to form training and test DataSets using **sklearn.model_selection.train_test_split()**.
#
# We will make them at the ratio of 73/27. Without shuffling. It means, that test samples are located in the end of **X** and **Y** DataSets.
#
# Input normalized DataSets: **X_train, X_test**
#
# Target normalized DataSets: **y_train, y_test**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(scaled_x, scaled_y, test_size=0.32, shuffle=False)

# %% [markdown]
# All the data is normalized now. However, in order to compare to results, we need real scale data of the training and test DataSet:

# %%
res_train = scaler_y.inverse_transform(y_train).flatten()
res_test = scaler_y.inverse_transform(y_test).flatten()

# %% [markdown]
# Target real scale DataSets: **res_train, res_test**.

# %% [markdown]
# # Linear Regression

# %% [markdown]
# First of all, we should create a model. We will test three type of models. A Linear regression, a Multilayer Neural Network with Backpropagation and a Long Short-Term Memory Neural Network.
# Let's create a **LinearRegression()**

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %% [markdown]
# After that, our model should be fitted on the training DataSet. Regardless of the model type, the function fit() is used to do this.

# %%
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Then we can test it on the test DataSet and use it for prognostication.

# %%
y_pred_test_ln = regressor.predict(X_test)
y_pred_test_ln = scaler_y.inverse_transform(y_pred_test_ln).flatten()

# %% [markdown]
# Let's analyze the results accuracy using **sklearn.metrics**.

# %%
from sklearn import metrics
print("Correlation train", regressor.score(X_train, y_train))
print("Correlation test", regressor.score(X_test, y_test))
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_test_ln))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_test_ln))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_test_ln)))
# Out:
# Correlation train 0.9968040612878395
# Correlation test 0.9872560154184292
# Mean Absolute Error: 51706.475155126034
# Mean Squared Error: 8393426094.392239
# Root Mean Squared Error: 91615.6432842789

# %% [markdown]
# # Back Propagation NN

# %% [markdown]
# The modern approach to the establishment of complex functional dependencies is the use of neural networks. A classical neural network is a **multilayer neural network with back propagation**.
#
# To do this, we will use the **keras** framework.
# First of all, we should create a Neural Network model as a separate function.
#
# A neural network is a sequence of layers. The function **Sequential()** is used to create a network.
#
# Let's create a network that consists of 2 hidden layers. Each of which consists of 100 neurons. **keras.layers.Dense()**.
#
# To avoid retraining problems, we will use additional layers **keras.layers.Dropout()**.
#
# The output layer will consist of one neuron, since we have only one value at the output.
#
# The model should be compiled for fitting and predicting: **keras.Model.compile()**.

# %%
def BP_model(X):
    """
    Multilayer neural network with back propagation.
    X: Input DataSet
    return: keras NN model
    """
    # create model
    model = Sequential() 
    model.add(Dense(100, input_dim=X.shape[1], kernel_initializer='normal', activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(100, kernel_initializer='normal', activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1, kernel_initializer='normal'))
    # Compile model
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %% [markdown]
# Once the model function is built, it is necessary to create a neural network directly and specify the learning parameters: **keras.wrappers.scikit_learn.KerasRegressor()**.
#
# Also we should define the number of fitting **epoch and batch size**.

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
epochs = 1000

batch_size=int(y_train.shape[0]*.1)

estimator = KerasRegressor(build_fn=BP_model, X=X_train, epochs=epochs, batch_size=batch_size, verbose=1)

# %% [markdown]
# Now, let’s train our model for **1000** epochs.
# It should be noted that the fitting process is very slow. Therefore, we saved our fitted model to a file.
# To save time, we will upload the fitted model.
# If you like, you can leave the parameter **fitting on True** to refit the model.
# If you like, you can leave the parameter **fitting_save on True** to resave the model.

# %%
fitting = True
fitting_save = True

import pickle

if fitting:
    history=estimator.fit(X_train,y_train, validation_data=(X_test,y_test)) # Fitting model
    if fitting_save:
        # Save model
        estimator.model.save('BP_saved_model.h5')
        print("Saved model to disk")
        with open('history.pickle', 'wb') as f:
            pickle.dump(history.history, f)
# load model 
from keras.models import load_model
estimator = KerasRegressor(build_fn=BP_model, X=X_train, epochs=epochs, batch_size=batch_size, verbose=1)
estimator.model = load_model('BP_saved_model.h5')    
with open('history.pickle', 'rb') as f:
    history = pickle.load(f)
print("Loaded model from disk")
# Out:
# User settings:
#
#    KMP_AFFINITY=granularity=fine,noverbose,compact,1,0
#    KMP_BLOCKTIME=0
#    KMP_DUPLICATE_LIB_OK=True
#    KMP_INIT_AT_FORK=FALSE
#    KMP_SETTINGS=1
#    KMP_WARNINGS=0
#
# Effective settings:
#
#    KMP_ABORT_DELAY=0
#    KMP_ADAPTIVE_LOCK_PROPS='1,1024'
#    KMP_ALIGN_ALLOC=64
#    KMP_ALL_THREADPRIVATE=128
#    KMP_ATOMIC_MODE=2
#    KMP_BLOCKTIME=0
#    KMP_CPUINFO_FILE: value is not defined
#    KMP_DETERMINISTIC_REDUCTION=false
#    KMP_DEVICE_THREAD_LIMIT=2147483647
#    KMP_DISP_NUM_BUFFERS=7
#    KMP_DUPLICATE_LIB_OK=true
#    KMP_ENABLE_TASK_THROTTLING=true
#    KMP_FORCE_REDUCTION: value is not defined
#    KMP_FOREIGN_THREADS_THREADPRIVATE=true
#    KMP_FORKJOIN_BARRIER='2,2'
#    KMP_FORKJOIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_GTID_MODE=3
#    KMP_HANDLE_SIGNALS=false
#    KMP_HOT_TEAMS_MAX_LEVEL=1
#    KMP_HOT_TEAMS_MODE=0
#    KMP_INIT_AT_FORK=true
#    KMP_LIBRARY=throughput
#    KMP_LOCK_KIND=queuing
#    KMP_MALLOC_POOL_INCR=1M
#    KMP_NUM_LOCKS_IN_BLOCK=1
#    KMP_PLAIN_BARRIER='2,2'
#    KMP_PLAIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_REDUCTION_BARRIER='1,1'
#    KMP_REDUCTION_BARRIER_PATTERN='hyper,hyper'
#    KMP_SCHEDULE='static,balanced;guided,iterative'
#    KMP_SETTINGS=true
#    KMP_SPIN_BACKOFF_PARAMS='4096,100'
#    KMP_STACKOFFSET=64
#    KMP_STACKPAD=0
#    KMP_STACKSIZE=8M
#    KMP_STORAGE_MAP=false
#    KMP_TASKING=2
#    KMP_TASKLOOP_MIN_TASKS=0
#    KMP_TASK_STEALING_CONSTRAINT=1
#    KMP_TEAMS_THREAD_LIMIT=4
#    KMP_TOPOLOGY_METHOD=all
#    KMP_USE_YIELD=1
#    KMP_VERSION=false
#    KMP_WARNINGS=false
#    OMP_AFFINITY_FORMAT='OMP: pid %P tid %i thread %n bound to OS proc set {%A}'
#    OMP_ALLOCATOR=omp_default_mem_alloc
#    OMP_CANCELLATION=false
#    OMP_DEFAULT_DEVICE=0
#    OMP_DISPLAY_AFFINITY=false
#    OMP_DISPLAY_ENV=false
#    OMP_DYNAMIC=false
#    OMP_MAX_ACTIVE_LEVELS=1
#    OMP_MAX_TASK_PRIORITY=0
#    OMP_NESTED: deprecated; max-active-levels-var=1
#    OMP_NUM_THREADS: value is not defined
#    OMP_PLACES: value is not defined
#    OMP_PROC_BIND='intel'
#    OMP_SCHEDULE='static'
#    OMP_STACKSIZE=8M
#    OMP_TARGET_OFFLOAD=DEFAULT
#    OMP_THREAD_LIMIT=2147483647
#    OMP_WAIT_POLICY=PASSIVE
#    KMP_AFFINITY='noverbose,warnings,respect,granularity=fine,compact,1,0'
#
# 2022-03-03 03:20:22.119545: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2022-03-03 03:20:22.330962: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/1000
# 11/11 [==============================] - 1s 26ms/step - loss: 0.0364 - val_loss: 0.0127
# Epoch 2/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0117 - val_loss: 0.0146
# Epoch 3/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0072 - val_loss: 0.0089
# Epoch 4/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0050 - val_loss: 0.0081
# Epoch 5/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0036 - val_loss: 0.0065
# Epoch 6/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0034 - val_loss: 0.0058
# Epoch 7/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0030 - val_loss: 0.0045
# Epoch 8/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0027 - val_loss: 0.0039
# Epoch 9/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0023 - val_loss: 0.0030
# Epoch 10/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0047 - val_loss: 0.0034
# Epoch 11/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0026 - val_loss: 0.0029
# Epoch 12/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 13/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 14/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 15/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 16/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 17/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 18/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 19/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.9823e-04 - val_loss: 0.0016
# Epoch 20/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 21/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 22/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 23/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 24/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 25/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 26/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 27/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 28/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 29/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 30/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 31/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 32/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 33/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 34/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 35/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 36/1000
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 37/1000
# 11/11 [==============================] - 0s 13ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 38/1000
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 39/1000
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 40/1000
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 41/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 42/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.3255e-04 - val_loss: 0.0013
# Epoch 43/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.7939e-04 - val_loss: 0.0014
# Epoch 44/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 45/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 46/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 47/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 48/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.1554e-04 - val_loss: 0.0010
# Epoch 49/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 50/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0025
# Epoch 51/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 52/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 53/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.4244e-04 - val_loss: 0.0014
# Epoch 54/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 55/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 56/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0044 - val_loss: 0.0038
# Epoch 57/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0017
# Epoch 58/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 59/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 9.7440e-04
# Epoch 60/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 61/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 9.4521e-04
# Epoch 62/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 63/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 64/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 65/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.9544e-04 - val_loss: 9.2526e-04
# Epoch 66/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 67/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 9.5512e-04
# Epoch 68/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0016 - val_loss: 9.6033e-04
# Epoch 69/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.9916e-04 - val_loss: 0.0020
# Epoch 70/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.8445e-04 - val_loss: 9.7431e-04
# Epoch 71/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 72/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 73/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.7523e-04 - val_loss: 0.0014
# Epoch 74/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.3628e-04 - val_loss: 0.0016
# Epoch 75/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 76/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.7749e-04 - val_loss: 0.0011
# Epoch 77/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.7348e-04 - val_loss: 0.0012
# Epoch 78/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 79/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.8719e-04 - val_loss: 0.0011
# Epoch 80/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 81/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 82/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.1126e-04 - val_loss: 0.0012
# Epoch 83/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.0329e-04 - val_loss: 9.2321e-04
# Epoch 84/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 85/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 86/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.8937e-04 - val_loss: 0.0013
# Epoch 87/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 9.2372e-04 - val_loss: 0.0013
# Epoch 88/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.2087e-04 - val_loss: 7.9995e-04
# Epoch 89/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 90/1000
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0013 - val_loss: 8.9244e-04
# Epoch 91/1000
# 11/11 [==============================] - 0s 11ms/step - loss: 8.5776e-04 - val_loss: 0.0015
# Epoch 92/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 93/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0016 - val_loss: 8.2437e-04
# Epoch 94/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 95/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 96/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.6415e-04 - val_loss: 0.0014
# Epoch 97/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 98/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 99/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 100/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.2131e-04 - val_loss: 0.0011
# Epoch 101/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 102/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.4840e-04 - val_loss: 0.0012
# Epoch 103/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.3197e-04 - val_loss: 9.8643e-04
# Epoch 104/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.9196e-04 - val_loss: 0.0011
# Epoch 105/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 9.5720e-04 - val_loss: 8.9814e-04
# Epoch 106/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 107/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.8132e-04 - val_loss: 0.0013
# Epoch 108/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.4257e-04 - val_loss: 0.0011
# Epoch 109/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.9108e-04 - val_loss: 0.0011
# Epoch 110/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.2248e-04 - val_loss: 9.2896e-04
# Epoch 111/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.7199e-04 - val_loss: 0.0018
# Epoch 112/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 9.9571e-04
# Epoch 113/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.5500e-04 - val_loss: 0.0011
# Epoch 114/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.0584e-04 - val_loss: 8.7082e-04
# Epoch 115/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.6548e-04 - val_loss: 0.0014
# Epoch 116/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.7349e-04 - val_loss: 9.4653e-04
# Epoch 117/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 118/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.6158e-04 - val_loss: 0.0013
# Epoch 119/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 8.4093e-04
# Epoch 120/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 121/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.4647e-04 - val_loss: 7.6509e-04
# Epoch 122/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 123/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.1403e-04 - val_loss: 9.8342e-04
# Epoch 124/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.6773e-04 - val_loss: 9.7113e-04
# Epoch 125/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 126/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.5385e-04 - val_loss: 7.3560e-04
# Epoch 127/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.8479e-04 - val_loss: 8.8495e-04
# Epoch 128/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.5210e-04 - val_loss: 0.0010
# Epoch 129/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.9921e-04 - val_loss: 7.4583e-04
# Epoch 130/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 7.4652e-04 - val_loss: 0.0010
# Epoch 131/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.3516e-04 - val_loss: 9.4047e-04
# Epoch 132/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 133/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 9.3590e-04
# Epoch 134/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.5455e-04 - val_loss: 0.0011
# Epoch 135/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.6610e-04 - val_loss: 0.0010
# Epoch 136/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.8293e-04 - val_loss: 9.9837e-04
# Epoch 137/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.8933e-04 - val_loss: 9.6518e-04
# Epoch 138/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.3930e-04 - val_loss: 0.0012
# Epoch 139/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.8809e-04 - val_loss: 0.0011
# Epoch 140/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 141/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 8.4787e-04
# Epoch 142/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.4054e-04 - val_loss: 0.0014
# Epoch 143/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.7442e-04 - val_loss: 9.4323e-04
# Epoch 144/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 145/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 9.0856e-04
# Epoch 146/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.1651e-04 - val_loss: 8.4028e-04
# Epoch 147/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.0944e-04 - val_loss: 0.0012
# Epoch 148/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0010 - val_loss: 9.4054e-04
# Epoch 149/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0010 - val_loss: 8.3921e-04
# Epoch 150/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0030
# Epoch 151/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 8.2759e-04
# Epoch 152/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.6718e-04 - val_loss: 9.7354e-04
# Epoch 153/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 154/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.8610e-04 - val_loss: 7.7660e-04
# Epoch 155/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.6541e-04 - val_loss: 0.0015
# Epoch 156/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.3376e-04 - val_loss: 7.7038e-04
# Epoch 157/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.8261e-04 - val_loss: 8.6274e-04
# Epoch 158/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.2153e-04 - val_loss: 0.0013
# Epoch 159/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.9194e-04 - val_loss: 8.7663e-04
# Epoch 160/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.7103e-04 - val_loss: 0.0014
# Epoch 161/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.9641e-04 - val_loss: 8.5039e-04
# Epoch 162/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 163/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.6111e-04 - val_loss: 8.2359e-04
# Epoch 164/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0010 - val_loss: 8.7643e-04
# Epoch 165/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.7022e-04 - val_loss: 8.9714e-04
# Epoch 166/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.0776e-04 - val_loss: 0.0012
# Epoch 167/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.1429e-04 - val_loss: 7.0250e-04
# Epoch 168/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 169/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0010 - val_loss: 7.9471e-04
# Epoch 170/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.2065e-04 - val_loss: 0.0017
# Epoch 171/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.5194e-04 - val_loss: 0.0011
# Epoch 172/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.1997e-04 - val_loss: 0.0012
# Epoch 173/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.2071e-04 - val_loss: 8.6159e-04
# Epoch 174/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.5970e-04 - val_loss: 8.5511e-04
# Epoch 175/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.4747e-04 - val_loss: 8.3785e-04
# Epoch 176/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.3283e-04 - val_loss: 0.0010
# Epoch 177/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.0118e-04 - val_loss: 9.6919e-04
# Epoch 178/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.4045e-04 - val_loss: 0.0018
# Epoch 179/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 7.5077e-04
# Epoch 180/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 181/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.6139e-04 - val_loss: 9.5747e-04
# Epoch 182/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.1970e-04 - val_loss: 0.0015
# Epoch 183/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 8.9417e-04
# Epoch 184/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.6512e-04 - val_loss: 0.0011
# Epoch 185/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.8235e-04 - val_loss: 9.3742e-04
# Epoch 186/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.9056e-04 - val_loss: 9.3191e-04
# Epoch 187/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.7747e-04 - val_loss: 0.0010
# Epoch 188/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.0353e-04 - val_loss: 0.0013
# Epoch 189/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.8766e-04 - val_loss: 6.8656e-04
# Epoch 190/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.3899e-04 - val_loss: 0.0013
# Epoch 191/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.3563e-04 - val_loss: 9.5605e-04
# Epoch 192/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.7571e-04 - val_loss: 7.5727e-04
# Epoch 193/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 194/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.7450e-04 - val_loss: 7.7572e-04
# Epoch 195/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.2391e-04 - val_loss: 0.0012
# Epoch 196/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.6137e-04 - val_loss: 0.0012
# Epoch 197/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.9909e-04 - val_loss: 0.0010
# Epoch 198/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.3939e-04 - val_loss: 0.0012
# Epoch 199/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.3600e-04 - val_loss: 9.5737e-04
# Epoch 200/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.4439e-04 - val_loss: 7.0137e-04
# Epoch 201/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.5884e-04 - val_loss: 0.0013
# Epoch 202/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0010 - val_loss: 9.0576e-04
# Epoch 203/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.7379e-04 - val_loss: 7.5949e-04
# Epoch 204/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0028 - val_loss: 0.0033
# Epoch 205/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 206/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.9969e-04 - val_loss: 0.0016
# Epoch 207/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 208/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.6995e-04 - val_loss: 0.0013
# Epoch 209/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 7.3406e-04
# Epoch 210/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.6425e-04 - val_loss: 0.0016
# Epoch 211/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 8.3635e-04
# Epoch 212/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.1684e-04 - val_loss: 0.0010
# Epoch 213/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 5.8783e-04 - val_loss: 9.5443e-04
# Epoch 214/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.8363e-04 - val_loss: 7.7119e-04
# Epoch 215/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0030 - val_loss: 0.0022
# Epoch 216/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 217/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 218/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 8.0631e-04
# Epoch 219/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 220/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.3839e-04 - val_loss: 8.9545e-04
# Epoch 221/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.7379e-04 - val_loss: 0.0013
# Epoch 222/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.1849e-04 - val_loss: 8.0234e-04
# Epoch 223/1000
# 11/11 [==============================] - 0s 13ms/step - loss: 9.7820e-04 - val_loss: 9.5798e-04
# Epoch 224/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.0142e-04 - val_loss: 8.1390e-04
# Epoch 225/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.2008e-04 - val_loss: 0.0014
# Epoch 226/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0010 - val_loss: 9.3382e-04
# Epoch 227/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.7728e-04 - val_loss: 9.8508e-04
# Epoch 228/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.3211e-04 - val_loss: 9.1550e-04
# Epoch 229/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.8859e-04 - val_loss: 9.0726e-04
# Epoch 230/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.6511e-04 - val_loss: 0.0012
# Epoch 231/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.0811e-04 - val_loss: 6.6284e-04
# Epoch 232/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.5039e-04 - val_loss: 0.0017
# Epoch 233/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0010 - val_loss: 6.8288e-04
# Epoch 234/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.1292e-04 - val_loss: 7.5707e-04
# Epoch 235/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.4908e-04 - val_loss: 9.3169e-04
# Epoch 236/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.7559e-04 - val_loss: 7.2696e-04
# Epoch 237/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.3794e-04 - val_loss: 6.7330e-04
# Epoch 238/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.2051e-04 - val_loss: 0.0013
# Epoch 239/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.2063e-04 - val_loss: 6.5459e-04
# Epoch 240/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.4275e-04 - val_loss: 0.0012
# Epoch 241/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.3289e-04 - val_loss: 7.0932e-04
# Epoch 242/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.4938e-04 - val_loss: 0.0011
# Epoch 243/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.6203e-04 - val_loss: 7.6349e-04
# Epoch 244/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.9270e-04 - val_loss: 8.0277e-04
# Epoch 245/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.1898e-04 - val_loss: 0.0016
# Epoch 246/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 6.5352e-04
# Epoch 247/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.3638e-04 - val_loss: 0.0010
# Epoch 248/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.8378e-04 - val_loss: 0.0010
# Epoch 249/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.9044e-04 - val_loss: 7.5254e-04
# Epoch 250/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0010 - val_loss: 6.8370e-04
# Epoch 251/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 252/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0010 - val_loss: 8.4410e-04
# Epoch 253/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.7279e-04 - val_loss: 0.0013
# Epoch 254/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.8024e-04 - val_loss: 6.7702e-04
# Epoch 255/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.2980e-04 - val_loss: 0.0012
# Epoch 256/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.8130e-04 - val_loss: 0.0011
# Epoch 257/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.4486e-04 - val_loss: 8.6139e-04
# Epoch 258/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.6181e-04 - val_loss: 0.0011
# Epoch 259/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.4666e-04 - val_loss: 7.9110e-04
# Epoch 260/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.8207e-04 - val_loss: 9.6870e-04
# Epoch 261/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 5.8739e-04 - val_loss: 9.9790e-04
# Epoch 262/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.3315e-04 - val_loss: 9.5907e-04
# Epoch 263/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 8.2461e-04 - val_loss: 6.5889e-04
# Epoch 264/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 5.7038e-04 - val_loss: 8.7707e-04
# Epoch 265/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 5.8319e-04 - val_loss: 0.0010
# Epoch 266/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 4.5019e-04 - val_loss: 0.0011
# Epoch 267/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 5.5838e-04 - val_loss: 7.5908e-04
# Epoch 268/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0010 - val_loss: 7.7798e-04
# Epoch 269/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.4866e-04 - val_loss: 9.3659e-04
# Epoch 270/1000
# 11/11 [==============================] - 0s 10ms/step - loss: 6.1937e-04 - val_loss: 8.6220e-04
# Epoch 271/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 5.9891e-04 - val_loss: 8.4943e-04
# Epoch 272/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.7396e-04 - val_loss: 9.7300e-04
# Epoch 273/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.3374e-04 - val_loss: 0.0010
# Epoch 274/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.7655e-04 - val_loss: 6.1482e-04
# Epoch 275/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 276/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.4747e-04 - val_loss: 0.0014
# Epoch 277/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 7.3335e-04
# Epoch 278/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 6.7371e-04
# Epoch 279/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 280/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.7392e-04 - val_loss: 7.2046e-04
# Epoch 281/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.1276e-04 - val_loss: 8.7617e-04
# Epoch 282/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.7319e-04 - val_loss: 9.4130e-04
# Epoch 283/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.6147e-04 - val_loss: 8.9446e-04
# Epoch 284/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.2614e-04 - val_loss: 0.0010
# Epoch 285/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.7700e-04 - val_loss: 0.0012
# Epoch 286/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.9424e-04 - val_loss: 7.1562e-04
# Epoch 287/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.2333e-04 - val_loss: 6.5080e-04
# Epoch 288/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.9554e-04 - val_loss: 0.0013
# Epoch 289/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.6500e-04 - val_loss: 7.6410e-04
# Epoch 290/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.8960e-04 - val_loss: 6.7374e-04
# Epoch 291/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0010 - val_loss: 0.0017
# Epoch 292/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.5489e-04 - val_loss: 6.3097e-04
# Epoch 293/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.3670e-04 - val_loss: 8.6907e-04
# Epoch 294/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 7.7644e-04
# Epoch 295/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 296/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 8.2032e-04
# Epoch 297/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.3878e-04 - val_loss: 0.0012
# Epoch 298/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.5222e-04 - val_loss: 9.8728e-04
# Epoch 299/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.7936e-04 - val_loss: 6.7220e-04
# Epoch 300/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0010 - val_loss: 7.3796e-04
# Epoch 301/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.4495e-04 - val_loss: 8.8812e-04
# Epoch 302/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.5414e-04 - val_loss: 8.5715e-04
# Epoch 303/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.4784e-04 - val_loss: 6.7920e-04
# Epoch 304/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.2068e-04 - val_loss: 0.0011
# Epoch 305/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.4817e-04 - val_loss: 6.8217e-04
# Epoch 306/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.5497e-04 - val_loss: 8.8401e-04
# Epoch 307/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.2114e-04 - val_loss: 6.8633e-04
# Epoch 308/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.8609e-04 - val_loss: 9.4256e-04
# Epoch 309/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.3146e-04 - val_loss: 8.5065e-04
# Epoch 310/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 5.4042e-04 - val_loss: 7.1459e-04
# Epoch 311/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.3226e-04 - val_loss: 9.9771e-04
# Epoch 312/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.7170e-04 - val_loss: 9.5075e-04
# Epoch 313/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.9610e-04 - val_loss: 8.9708e-04
# Epoch 314/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 4.9209e-04 - val_loss: 7.9599e-04
# Epoch 315/1000
# 11/11 [==============================] - 0s 10ms/step - loss: 6.3899e-04 - val_loss: 7.1535e-04
# Epoch 316/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.8811e-04 - val_loss: 8.9304e-04
# Epoch 317/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.7868e-04 - val_loss: 9.3487e-04
# Epoch 318/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.4081e-04 - val_loss: 6.1112e-04
# Epoch 319/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.5694e-04 - val_loss: 9.6605e-04
# Epoch 320/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.9648e-04 - val_loss: 8.5218e-04
# Epoch 321/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0017 - val_loss: 8.0764e-04
# Epoch 322/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 323/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 8.7978e-04
# Epoch 324/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.4906e-04 - val_loss: 6.9477e-04
# Epoch 325/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.5229e-04 - val_loss: 7.2928e-04
# Epoch 326/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.7470e-04 - val_loss: 0.0011
# Epoch 327/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.4597e-04 - val_loss: 6.4487e-04
# Epoch 328/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.9554e-04 - val_loss: 0.0010
# Epoch 329/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.5358e-04 - val_loss: 8.4146e-04
# Epoch 330/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.1515e-04 - val_loss: 8.2508e-04
# Epoch 331/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0010 - val_loss: 7.3354e-04
# Epoch 332/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.2232e-04 - val_loss: 8.6197e-04
# Epoch 333/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.6552e-04 - val_loss: 6.3779e-04
# Epoch 334/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.0437e-04 - val_loss: 8.2265e-04
# Epoch 335/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.5915e-04 - val_loss: 8.5887e-04
# Epoch 336/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.6815e-04 - val_loss: 8.6122e-04
# Epoch 337/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.5298e-04 - val_loss: 0.0011
# Epoch 338/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.4690e-04 - val_loss: 8.0606e-04
# Epoch 339/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.0854e-04 - val_loss: 6.9534e-04
# Epoch 340/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 8.9254e-04
# Epoch 341/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.8127e-04 - val_loss: 7.5536e-04
# Epoch 342/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.6074e-04 - val_loss: 7.3861e-04
# Epoch 343/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.9969e-04 - val_loss: 0.0010
# Epoch 344/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.1559e-04 - val_loss: 8.9208e-04
# Epoch 345/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.4107e-04 - val_loss: 6.8172e-04
# Epoch 346/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.2237e-04 - val_loss: 0.0014
# Epoch 347/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.8387e-04 - val_loss: 8.7664e-04
# Epoch 348/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0022 - val_loss: 9.0001e-04
# Epoch 349/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 350/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.6968e-04 - val_loss: 8.5301e-04
# Epoch 351/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.4107e-04 - val_loss: 7.4485e-04
# Epoch 352/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.1148e-04 - val_loss: 0.0014
# Epoch 353/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.3938e-04 - val_loss: 6.9452e-04
# Epoch 354/1000
# 11/11 [==============================] - 0s 12ms/step - loss: 7.9856e-04 - val_loss: 6.7430e-04
# Epoch 355/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.7731e-04 - val_loss: 0.0015
# Epoch 356/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.9280e-04 - val_loss: 6.2344e-04
# Epoch 357/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 7.0427e-04
# Epoch 358/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.8725e-04 - val_loss: 9.8892e-04
# Epoch 359/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 5.4195e-04 - val_loss: 6.5644e-04
# Epoch 360/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.0688e-04 - val_loss: 0.0010
# Epoch 361/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.4706e-04 - val_loss: 7.8471e-04
# Epoch 362/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 8.3547e-04 - val_loss: 8.0616e-04
# Epoch 363/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.5484e-04 - val_loss: 0.0014
# Epoch 364/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.7158e-04 - val_loss: 7.3364e-04
# Epoch 365/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.7948e-04 - val_loss: 9.7201e-04
# Epoch 366/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.6849e-04 - val_loss: 7.3722e-04
# Epoch 367/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 5.2509e-04 - val_loss: 8.2716e-04
# Epoch 368/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.6180e-04 - val_loss: 0.0011
# Epoch 369/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.8780e-04 - val_loss: 9.7463e-04
# Epoch 370/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.3024e-04 - val_loss: 9.6210e-04
# Epoch 371/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.2672e-04 - val_loss: 5.8601e-04
# Epoch 372/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.5737e-04 - val_loss: 0.0014
# Epoch 373/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.0678e-04 - val_loss: 7.3750e-04
# Epoch 374/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 6.5724e-04 - val_loss: 6.1890e-04
# Epoch 375/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 8.4114e-04
# Epoch 376/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.8093e-04 - val_loss: 6.1956e-04
# Epoch 377/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 0.0025
# Epoch 378/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0021 - val_loss: 7.8848e-04
# Epoch 379/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.3232e-04 - val_loss: 9.1014e-04
# Epoch 380/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.2018e-04 - val_loss: 8.9551e-04
# Epoch 381/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.3794e-04 - val_loss: 0.0011
# Epoch 382/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.2912e-04 - val_loss: 0.0010
# Epoch 383/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.3638e-04 - val_loss: 8.9131e-04
# Epoch 384/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.1477e-04 - val_loss: 0.0010
# Epoch 385/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.1980e-04 - val_loss: 5.9711e-04
# Epoch 386/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.5405e-04 - val_loss: 0.0013
# Epoch 387/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 4.7203e-04 - val_loss: 8.6622e-04
# Epoch 388/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 7.2591e-04 - val_loss: 8.0612e-04
# Epoch 389/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 5.8669e-04 - val_loss: 7.9959e-04
# Epoch 390/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.4495e-04 - val_loss: 9.3526e-04
# Epoch 391/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.9981e-04 - val_loss: 6.6443e-04
# Epoch 392/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 393/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.7378e-04 - val_loss: 6.3784e-04
# Epoch 394/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 395/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 8.5533e-04
# Epoch 396/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.3321e-04 - val_loss: 6.8470e-04
# Epoch 397/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.5229e-04 - val_loss: 0.0010
# Epoch 398/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.2766e-04 - val_loss: 0.0010
# Epoch 399/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.0619e-04 - val_loss: 0.0011
# Epoch 400/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.4993e-04 - val_loss: 6.3144e-04
# Epoch 401/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.6745e-04 - val_loss: 9.9709e-04
# Epoch 402/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.1583e-04 - val_loss: 8.3276e-04
# Epoch 403/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.3514e-04 - val_loss: 9.1197e-04
# Epoch 404/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.4138e-04 - val_loss: 8.8199e-04
# Epoch 405/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.6872e-04 - val_loss: 0.0012
# Epoch 406/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.9399e-04 - val_loss: 6.1516e-04
# Epoch 407/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.1338e-04 - val_loss: 0.0010
# Epoch 408/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.6175e-04 - val_loss: 7.8238e-04
# Epoch 409/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.0469e-04 - val_loss: 8.1120e-04
# Epoch 410/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.2866e-04 - val_loss: 6.2616e-04
# Epoch 411/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.9174e-04 - val_loss: 9.2678e-04
# Epoch 412/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.0003e-04 - val_loss: 7.0501e-04
# Epoch 413/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.6412e-04 - val_loss: 7.1709e-04
# Epoch 414/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.8290e-04 - val_loss: 0.0011
# Epoch 415/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.0244e-04 - val_loss: 6.1782e-04
# Epoch 416/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.8665e-04 - val_loss: 0.0011
# Epoch 417/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.5239e-04 - val_loss: 6.9611e-04
# Epoch 418/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.2514e-04 - val_loss: 7.5627e-04
# Epoch 419/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.3990e-04 - val_loss: 0.0011
# Epoch 420/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.4153e-04 - val_loss: 6.0054e-04
# Epoch 421/1000
# 11/11 [==============================] - 0s 15ms/step - loss: 8.0670e-04 - val_loss: 0.0012
# Epoch 422/1000
# 11/11 [==============================] - 0s 11ms/step - loss: 6.9304e-04 - val_loss: 8.5727e-04
# Epoch 423/1000
# 11/11 [==============================] - 0s 12ms/step - loss: 6.8726e-04 - val_loss: 6.6863e-04
# Epoch 424/1000
# 11/11 [==============================] - 0s 21ms/step - loss: 8.2515e-04 - val_loss: 9.8730e-04
# Epoch 425/1000
# 11/11 [==============================] - 0s 17ms/step - loss: 6.0369e-04 - val_loss: 7.6518e-04
# Epoch 426/1000
# 11/11 [==============================] - 0s 12ms/step - loss: 7.8335e-04 - val_loss: 6.1530e-04
# Epoch 427/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.0269e-04 - val_loss: 0.0011
# Epoch 428/1000
# ...
# Epoch 855/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.3122e-04 - val_loss: 7.1579e-04
# Epoch 856/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.2604e-04 - val_loss: 7.7526e-04
# Epoch 857/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.0292e-04 - val_loss: 7.1371e-04
# Epoch 858/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.6979e-04 - val_loss: 6.2473e-04
# Epoch 859/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.6657e-04 - val_loss: 0.0010
# Epoch 860/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.2377e-04 - val_loss: 6.4309e-04
# Epoch 861/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.6563e-04 - val_loss: 0.0014
# Epoch 862/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 5.0751e-04 - val_loss: 7.1557e-04
# Epoch 863/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 7.1832e-04 - val_loss: 0.0010
# Epoch 864/1000
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 865/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 866/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.5501e-04 - val_loss: 6.3897e-04
# Epoch 867/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.4653e-04 - val_loss: 0.0011
# Epoch 868/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.9887e-04 - val_loss: 5.9705e-04
# Epoch 869/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.2338e-04 - val_loss: 7.4048e-04
# Epoch 870/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.2097e-04 - val_loss: 9.7027e-04
# Epoch 871/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.2772e-04 - val_loss: 7.2134e-04
# Epoch 872/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.1897e-04 - val_loss: 5.4303e-04
# Epoch 873/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.7831e-04 - val_loss: 0.0017
# Epoch 874/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.1936e-04 - val_loss: 5.8377e-04
# Epoch 875/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.4694e-04 - val_loss: 8.8831e-04
# Epoch 876/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.1524e-04 - val_loss: 8.3031e-04
# Epoch 877/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.0421e-04 - val_loss: 8.0409e-04
# Epoch 878/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.3460e-04 - val_loss: 9.0022e-04
# Epoch 879/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.0617e-04 - val_loss: 7.9391e-04
# Epoch 880/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.1675e-04 - val_loss: 7.7947e-04
# Epoch 881/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.6242e-04 - val_loss: 6.7043e-04
# Epoch 882/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.0971e-04 - val_loss: 0.0010
# Epoch 883/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.8172e-04 - val_loss: 8.3421e-04
# Epoch 884/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 4.8565e-04 - val_loss: 7.1569e-04
# Epoch 885/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.6225e-04 - val_loss: 7.6135e-04
# Epoch 886/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.0230e-04 - val_loss: 5.1887e-04
# Epoch 887/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.7124e-04 - val_loss: 0.0010
# Epoch 888/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.7035e-04 - val_loss: 6.3983e-04
# Epoch 889/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.7886e-04 - val_loss: 8.6234e-04
# Epoch 890/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.1322e-04 - val_loss: 6.8611e-04
# Epoch 891/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 5.0217e-04 - val_loss: 8.6876e-04
# Epoch 892/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.4951e-04 - val_loss: 0.0010
# Epoch 893/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.2755e-04 - val_loss: 0.0011
# Epoch 894/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 6.2518e-04
# Epoch 895/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.8057e-04 - val_loss: 0.0014
# Epoch 896/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.2632e-04 - val_loss: 8.9412e-04
# Epoch 897/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.6303e-04 - val_loss: 7.6003e-04
# Epoch 898/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 5.4894e-04 - val_loss: 7.3611e-04
# Epoch 899/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.3542e-04 - val_loss: 7.8612e-04
# Epoch 900/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.6913e-04 - val_loss: 0.0010
# Epoch 901/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.5515e-04 - val_loss: 5.6716e-04
# Epoch 902/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0010 - val_loss: 8.8534e-04
# Epoch 903/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 5.7163e-04 - val_loss: 7.6210e-04
# Epoch 904/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 5.2876e-04 - val_loss: 8.8930e-04
# Epoch 905/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.0411e-04 - val_loss: 7.5736e-04
# Epoch 906/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.9380e-04 - val_loss: 6.7625e-04
# Epoch 907/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.6950e-04 - val_loss: 0.0012
# Epoch 908/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.2074e-04 - val_loss: 6.3484e-04
# Epoch 909/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.4126e-04 - val_loss: 6.0383e-04
# Epoch 910/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.3092e-04 - val_loss: 0.0013
# Epoch 911/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.3022e-04 - val_loss: 9.2420e-04
# Epoch 912/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.3412e-04 - val_loss: 6.2739e-04
# Epoch 913/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.6532e-04 - val_loss: 0.0013
# Epoch 914/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.8195e-04 - val_loss: 6.9560e-04
# Epoch 915/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.2813e-04 - val_loss: 7.3306e-04
# Epoch 916/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.1361e-04 - val_loss: 6.9176e-04
# Epoch 917/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 5.2193e-04 - val_loss: 0.0011
# Epoch 918/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.3528e-04 - val_loss: 0.0011
# Epoch 919/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.8973e-04 - val_loss: 6.8564e-04
# Epoch 920/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.8700e-04 - val_loss: 8.0745e-04
# Epoch 921/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.5472e-04 - val_loss: 9.8448e-04
# Epoch 922/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.3067e-04 - val_loss: 7.5934e-04
# Epoch 923/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.5167e-04 - val_loss: 7.8297e-04
# Epoch 924/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 4.3731e-04 - val_loss: 0.0010
# Epoch 925/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.3977e-04 - val_loss: 8.0999e-04
# Epoch 926/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.8300e-04 - val_loss: 6.0695e-04
# Epoch 927/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.9316e-04 - val_loss: 0.0011
# Epoch 928/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.2901e-04 - val_loss: 9.8439e-04
# Epoch 929/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.2763e-04 - val_loss: 5.7308e-04
# Epoch 930/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.9833e-04 - val_loss: 0.0011
# Epoch 931/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.5640e-04 - val_loss: 0.0010
# Epoch 932/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.1087e-04 - val_loss: 6.6911e-04
# Epoch 933/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.3583e-04 - val_loss: 9.0230e-04
# Epoch 934/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.4056e-04 - val_loss: 6.2277e-04
# Epoch 935/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.7653e-04 - val_loss: 0.0011
# Epoch 936/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.7009e-04 - val_loss: 5.9696e-04
# Epoch 937/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.4264e-04 - val_loss: 0.0013
# Epoch 938/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0010 - val_loss: 7.9220e-04
# Epoch 939/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.0185e-04 - val_loss: 8.4575e-04
# Epoch 940/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.3036e-04 - val_loss: 9.3167e-04
# Epoch 941/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.9853e-04 - val_loss: 7.7269e-04
# Epoch 942/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.2789e-04 - val_loss: 7.4238e-04
# Epoch 943/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 4.0641e-04 - val_loss: 8.2633e-04
# Epoch 944/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 5.5637e-04 - val_loss: 7.3685e-04
# Epoch 945/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 5.8828e-04 - val_loss: 7.1366e-04
# Epoch 946/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.0977e-04 - val_loss: 6.5235e-04
# Epoch 947/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 948/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.4061e-04 - val_loss: 5.8270e-04
# Epoch 949/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.1412e-04 - val_loss: 5.5579e-04
# Epoch 950/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 951/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 6.3223e-04
# Epoch 952/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.3491e-04 - val_loss: 8.2946e-04
# Epoch 953/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 5.8775e-04 - val_loss: 7.0578e-04
# Epoch 954/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.5316e-04 - val_loss: 5.5492e-04
# Epoch 955/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.5828e-04 - val_loss: 0.0016
# Epoch 956/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.4417e-04 - val_loss: 6.7117e-04
# Epoch 957/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.6416e-04 - val_loss: 9.1394e-04
# Epoch 958/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.6156e-04 - val_loss: 8.8948e-04
# Epoch 959/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.8890e-04 - val_loss: 9.1008e-04
# Epoch 960/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.3141e-04 - val_loss: 0.0012
# Epoch 961/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.7679e-04 - val_loss: 5.6978e-04
# Epoch 962/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.1476e-04 - val_loss: 0.0011
# Epoch 963/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.5375e-04 - val_loss: 6.3205e-04
# Epoch 964/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 5.8507e-04 - val_loss: 9.0420e-04
# Epoch 965/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 5.9231e-04 - val_loss: 7.5507e-04
# Epoch 966/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.7187e-04 - val_loss: 0.0012
# Epoch 967/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 5.8468e-04 - val_loss: 6.8862e-04
# Epoch 968/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 5.9121e-04 - val_loss: 6.8140e-04
# Epoch 969/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.2175e-04 - val_loss: 0.0018
# Epoch 970/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.4511e-04 - val_loss: 6.7314e-04
# Epoch 971/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 5.4113e-04 - val_loss: 8.4063e-04
# Epoch 972/1000
# 11/11 [==============================] - 0s 10ms/step - loss: 6.4336e-04 - val_loss: 6.3235e-04
# Epoch 973/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.9059e-04 - val_loss: 7.8621e-04
# Epoch 974/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.1840e-04 - val_loss: 0.0011
# Epoch 975/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.9077e-04 - val_loss: 5.3767e-04
# Epoch 976/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.7105e-04 - val_loss: 0.0011
# Epoch 977/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.1966e-04 - val_loss: 9.0981e-04
# Epoch 978/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 5.8933e-04 - val_loss: 6.5916e-04
# Epoch 979/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 4.5049e-04 - val_loss: 0.0013
# Epoch 980/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.0998e-04 - val_loss: 5.5456e-04
# Epoch 981/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.0319e-04 - val_loss: 7.0573e-04
# Epoch 982/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 983/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.0814e-04 - val_loss: 6.4810e-04
# Epoch 984/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.7939e-04 - val_loss: 0.0011
# Epoch 985/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.4318e-04 - val_loss: 8.1042e-04
# Epoch 986/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 9.1048e-04 - val_loss: 8.2965e-04
# Epoch 987/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.0765e-04 - val_loss: 9.4577e-04
# Epoch 988/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.3394e-04 - val_loss: 0.0010
# Epoch 989/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.3534e-04 - val_loss: 6.0873e-04
# Epoch 990/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 5.3906e-04 - val_loss: 5.9061e-04
# Epoch 991/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.4412e-04 - val_loss: 6.6720e-04
# Epoch 992/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 4.7356e-04 - val_loss: 7.3487e-04
# Epoch 993/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.7865e-04 - val_loss: 5.9972e-04
# Epoch 994/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.8705e-04 - val_loss: 0.0011
# Epoch 995/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 5.6945e-04
# Epoch 996/1000
# 11/11 [==============================] - 0s 12ms/step - loss: 5.1747e-04 - val_loss: 9.5918e-04
# Epoch 997/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.3542e-04 - val_loss: 9.9721e-04
# Epoch 998/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.6717e-04 - val_loss: 6.2511e-04
# Epoch 999/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.4831e-04 - val_loss: 9.4808e-04
# Epoch 1000/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.3356e-04 - val_loss: 5.9216e-04
# Saved model to disk
# Loaded model from disk

# %%
plt.figure()
plt.plot(history['loss'], label='train')
plt.plot(history['val_loss'], label='test')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.show()

# %% [markdown]
# As you can see, a Neural Network is well-fitted and no overfitting is observed.
# Let's calculate a prediction of the training (**res_train_ANN**) an test (**res_test_ANN**) sets.

# %% [markdown]
# Let's calculate a forecast and make an inverse normalization to real scale.

# %%
res_tr=estimator.predict(X_train)
res_ts=estimator.predict(X_test)
res_train_ANN=scaler_y.inverse_transform(res_tr.reshape(-1, 1)).flatten()
res_test_ANN=scaler_y.inverse_transform(res_ts.reshape(-1, 1)).flatten()
# Out:
# 11/11 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step

# %% [markdown]
# Let's compare the accuracy of a Linear Regression and a Neural Network.

# %%
print("Correlation train", np.corrcoef(res_train, res_train_ANN)[0,1])
print("Correlation train", np.corrcoef(res_test, res_test_ANN)[0,1])
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, res_test_ANN))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, res_test_ANN))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, res_test_ANN)))
# Out:
# Correlation train 0.998448607178335
# Correlation train 0.9911922894983044
# Mean Absolute Error: 51597.71995671751
# Mean Squared Error: 8402095380.421753
# Root Mean Squared Error: 91662.94442369693

# %% [markdown]
# We got slightly better results for a Neural Network than for a Linear Regression.

# %% [markdown]
# # Long Short-Term Memory - LSTM

# %% [markdown]
# Unlike standard feedforward neural networks, **LSTM** has feedback connections. It can process not only single data points, but also entire sequences of data (such as speech, video or time series).
#
# In case of time series, the neural network has one input and one output. However, there should be a vector of time series values for the previous time period on the input.

# %% [markdown]
# To do this, we should transform input DataSets into 3D shape.

# %%
train_x_LSTM = X_train.reshape((X_train.shape[0], 1, 14))
test_x_LSTM = X_test.reshape((X_test.shape[0], 1, 14))

# %% [markdown]
# Let's create an LSTM Neural Network consisting of one **LSTM** layer and one BP layer like in the previous case.
# In this case our NN will consist of 7 LSTM and 7 BP neurons only.

# %%
from keras.layers import LSTM

batch_size=int(y_train.shape[0]*.1)
model = Sequential()
model.add(LSTM(7, input_shape=(train_x_LSTM.shape[1], train_x_LSTM.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(7, kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(y_train.shape[1])) #activation='sigmoid'
model.compile(loss='mean_squared_error', optimizer='adam')

# %% [markdown]
# All subsequent steps of learning, storing, reading and predicting are similar to the ones we used with the previous neural network. You can see that only 420 epochs are enough for an LSTM.

# %%
fitting = True
fitting_save = True
epochs = 420

if fitting:
    history = model.fit(train_x_LSTM, y_train, epochs=epochs, batch_size=batch_size, validation_data=(test_x_LSTM, y_test), verbose=1, shuffle=False)    
    if fitting_save:
    # serialize model to JSON
        model_json = model.to_json()
        with open("LSTM_model.json", "w") as json_file:
            json_file.write(model_json)
        # serialize weights to HDF5
        model.save_weights("LSTM_model.h5")
        print("Saved model to disk")
        with open('history_LSTM.pickle', 'wb') as f:
            pickle.dump(history.history, f)
# load model  
from keras.models import model_from_json
json_file = open('LSTM_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
model = model_from_json(loaded_model_json)
# load weights into new model
model.load_weights("LSTM_model.h5")        
with open('history_LSTM.pickle', 'rb') as f:
    history = pickle.load(f)
print("Loaded model from disk")
# Out:
# Epoch 1/420
# 11/11 [==============================] - 3s 64ms/step - loss: 0.0586 - val_loss: 0.0408
# Epoch 2/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0537 - val_loss: 0.0372
# Epoch 3/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0491 - val_loss: 0.0341
# Epoch 4/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0448 - val_loss: 0.0315
# Epoch 5/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0433 - val_loss: 0.0294
# Epoch 6/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0395 - val_loss: 0.0277
# Epoch 7/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0393 - val_loss: 0.0263
# Epoch 8/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0361 - val_loss: 0.0250
# Epoch 9/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0347 - val_loss: 0.0239
# Epoch 10/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0314 - val_loss: 0.0229
# Epoch 11/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0318 - val_loss: 0.0219
# Epoch 12/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0314 - val_loss: 0.0210
# Epoch 13/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0279 - val_loss: 0.0201
# Epoch 14/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0251 - val_loss: 0.0191
# Epoch 15/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0264 - val_loss: 0.0182
# Epoch 16/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0234 - val_loss: 0.0172
# Epoch 17/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0241 - val_loss: 0.0162
# Epoch 18/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0214 - val_loss: 0.0153
# Epoch 19/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0174 - val_loss: 0.0144
# Epoch 20/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0191 - val_loss: 0.0135
# Epoch 21/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0158 - val_loss: 0.0127
# Epoch 22/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0126 - val_loss: 0.0119
# Epoch 23/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0157 - val_loss: 0.0112
# Epoch 24/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0127 - val_loss: 0.0106
# Epoch 25/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0150 - val_loss: 0.0101
# Epoch 26/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0156 - val_loss: 0.0097
# Epoch 27/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0119 - val_loss: 0.0093
# Epoch 28/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0118 - val_loss: 0.0090
# Epoch 29/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0094 - val_loss: 0.0088
# Epoch 30/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0122 - val_loss: 0.0086
# Epoch 31/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0128 - val_loss: 0.0084
# Epoch 32/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0124 - val_loss: 0.0083
# Epoch 33/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0119 - val_loss: 0.0081
# Epoch 34/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0107 - val_loss: 0.0080
# Epoch 35/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0109 - val_loss: 0.0079
# Epoch 36/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0084 - val_loss: 0.0078
# Epoch 37/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0094 - val_loss: 0.0077
# Epoch 38/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0096 - val_loss: 0.0076
# Epoch 39/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0078 - val_loss: 0.0075
# Epoch 40/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0096 - val_loss: 0.0074
# Epoch 41/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0100 - val_loss: 0.0074
# Epoch 42/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0089 - val_loss: 0.0073
# Epoch 43/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0110 - val_loss: 0.0072
# Epoch 44/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0106 - val_loss: 0.0071
# Epoch 45/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0123 - val_loss: 0.0070
# Epoch 46/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0078 - val_loss: 0.0070
# Epoch 47/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0088 - val_loss: 0.0069
# Epoch 48/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0127 - val_loss: 0.0068
# Epoch 49/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0080 - val_loss: 0.0067
# Epoch 50/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0100 - val_loss: 0.0066
# Epoch 51/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0105 - val_loss: 0.0065
# Epoch 52/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0105 - val_loss: 0.0065
# Epoch 53/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0103 - val_loss: 0.0064
# Epoch 54/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0100 - val_loss: 0.0063
# Epoch 55/420
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0089 - val_loss: 0.0062
# Epoch 56/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0067 - val_loss: 0.0061
# Epoch 57/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0113 - val_loss: 0.0060
# Epoch 58/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0101 - val_loss: 0.0060
# Epoch 59/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0087 - val_loss: 0.0059
# Epoch 60/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0104 - val_loss: 0.0058
# Epoch 61/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0078 - val_loss: 0.0057
# Epoch 62/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0092 - val_loss: 0.0056
# Epoch 63/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0078 - val_loss: 0.0055
# Epoch 64/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0062 - val_loss: 0.0054
# Epoch 65/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0084 - val_loss: 0.0054
# Epoch 66/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0094 - val_loss: 0.0053
# Epoch 67/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0102 - val_loss: 0.0052
# Epoch 68/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0078 - val_loss: 0.0052
# Epoch 69/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0077 - val_loss: 0.0051
# Epoch 70/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0080 - val_loss: 0.0051
# Epoch 71/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0070 - val_loss: 0.0050
# Epoch 72/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0086 - val_loss: 0.0049
# Epoch 73/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0069 - val_loss: 0.0049
# Epoch 74/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0096 - val_loss: 0.0048
# Epoch 75/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0070 - val_loss: 0.0047
# Epoch 76/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0066 - val_loss: 0.0047
# Epoch 77/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0080 - val_loss: 0.0046
# Epoch 78/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0080 - val_loss: 0.0045
# Epoch 79/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0084 - val_loss: 0.0044
# Epoch 80/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0070 - val_loss: 0.0044
# Epoch 81/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0063 - val_loss: 0.0043
# Epoch 82/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0066 - val_loss: 0.0042
# Epoch 83/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0079 - val_loss: 0.0042
# Epoch 84/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0088 - val_loss: 0.0041
# Epoch 85/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0083 - val_loss: 0.0040
# Epoch 86/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0067 - val_loss: 0.0039
# Epoch 87/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0092 - val_loss: 0.0039
# Epoch 88/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0069 - val_loss: 0.0038
# Epoch 89/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0064 - val_loss: 0.0038
# Epoch 90/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0095 - val_loss: 0.0037
# Epoch 91/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0077 - val_loss: 0.0036
# Epoch 92/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0075 - val_loss: 0.0036
# Epoch 93/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0083 - val_loss: 0.0036
# Epoch 94/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0070 - val_loss: 0.0035
# Epoch 95/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0085 - val_loss: 0.0035
# Epoch 96/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0080 - val_loss: 0.0034
# Epoch 97/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0068 - val_loss: 0.0034
# Epoch 98/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0075 - val_loss: 0.0033
# Epoch 99/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0082 - val_loss: 0.0033
# Epoch 100/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0075 - val_loss: 0.0032
# Epoch 101/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0096 - val_loss: 0.0032
# Epoch 102/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0048 - val_loss: 0.0032
# Epoch 103/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0079 - val_loss: 0.0031
# Epoch 104/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0062 - val_loss: 0.0031
# Epoch 105/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0079 - val_loss: 0.0030
# Epoch 106/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0089 - val_loss: 0.0030
# Epoch 107/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0060 - val_loss: 0.0029
# Epoch 108/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0108 - val_loss: 0.0029
# Epoch 109/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0072 - val_loss: 0.0029
# Epoch 110/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0064 - val_loss: 0.0029
# Epoch 111/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0057 - val_loss: 0.0028
# Epoch 112/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0058 - val_loss: 0.0028
# Epoch 113/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0059 - val_loss: 0.0028
# Epoch 114/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0063 - val_loss: 0.0027
# Epoch 115/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0082 - val_loss: 0.0027
# Epoch 116/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0082 - val_loss: 0.0027
# Epoch 117/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0074 - val_loss: 0.0027
# Epoch 118/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0074 - val_loss: 0.0026
# Epoch 119/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0080 - val_loss: 0.0026
# Epoch 120/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0070 - val_loss: 0.0026
# Epoch 121/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0076 - val_loss: 0.0026
# Epoch 122/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0080 - val_loss: 0.0026
# Epoch 123/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0063 - val_loss: 0.0026
# Epoch 124/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0062 - val_loss: 0.0026
# Epoch 125/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0064 - val_loss: 0.0026
# Epoch 126/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0075 - val_loss: 0.0025
# Epoch 127/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0053 - val_loss: 0.0025
# Epoch 128/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0057 - val_loss: 0.0025
# Epoch 129/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0058 - val_loss: 0.0025
# Epoch 130/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0053 - val_loss: 0.0024
# Epoch 131/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0062 - val_loss: 0.0024
# Epoch 132/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0079 - val_loss: 0.0024
# Epoch 133/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0074 - val_loss: 0.0024
# Epoch 134/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0074 - val_loss: 0.0024
# Epoch 135/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0075 - val_loss: 0.0023
# Epoch 136/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0062 - val_loss: 0.0023
# Epoch 137/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0079 - val_loss: 0.0023
# Epoch 138/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0060 - val_loss: 0.0023
# Epoch 139/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0064 - val_loss: 0.0023
# Epoch 140/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0090 - val_loss: 0.0023
# Epoch 141/420
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0022
# Epoch 142/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0072 - val_loss: 0.0022
# Epoch 143/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0077 - val_loss: 0.0022
# Epoch 144/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0075 - val_loss: 0.0022
# Epoch 145/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0069 - val_loss: 0.0021
# Epoch 146/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0051 - val_loss: 0.0021
# Epoch 147/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0062 - val_loss: 0.0021
# Epoch 148/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0066 - val_loss: 0.0021
# Epoch 149/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0093 - val_loss: 0.0021
# Epoch 150/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0065 - val_loss: 0.0021
# Epoch 151/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0058 - val_loss: 0.0022
# Epoch 152/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0058 - val_loss: 0.0021
# Epoch 153/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0074 - val_loss: 0.0021
# Epoch 154/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0074 - val_loss: 0.0021
# Epoch 155/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0059 - val_loss: 0.0020
# Epoch 156/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0071 - val_loss: 0.0020
# Epoch 157/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0066 - val_loss: 0.0020
# Epoch 158/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0067 - val_loss: 0.0020
# Epoch 159/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0058 - val_loss: 0.0020
# Epoch 160/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0054 - val_loss: 0.0021
# Epoch 161/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0102 - val_loss: 0.0021
# Epoch 162/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0055 - val_loss: 0.0020
# Epoch 163/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0078 - val_loss: 0.0020
# Epoch 164/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0053 - val_loss: 0.0019
# Epoch 165/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0075 - val_loss: 0.0019
# Epoch 166/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0071 - val_loss: 0.0019
# Epoch 167/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0071 - val_loss: 0.0019
# Epoch 168/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0064 - val_loss: 0.0019
# Epoch 169/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0060 - val_loss: 0.0019
# Epoch 170/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0068 - val_loss: 0.0019
# Epoch 171/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0080 - val_loss: 0.0019
# Epoch 172/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0062 - val_loss: 0.0019
# Epoch 173/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0052 - val_loss: 0.0019
# Epoch 174/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0056 - val_loss: 0.0018
# Epoch 175/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0066 - val_loss: 0.0019
# Epoch 176/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0062 - val_loss: 0.0019
# Epoch 177/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0046 - val_loss: 0.0019
# Epoch 178/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0076 - val_loss: 0.0019
# Epoch 179/420
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0059 - val_loss: 0.0019
# Epoch 180/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0072 - val_loss: 0.0019
# Epoch 181/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0072 - val_loss: 0.0019
# Epoch 182/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0060 - val_loss: 0.0019
# Epoch 183/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0064 - val_loss: 0.0020
# Epoch 184/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0059 - val_loss: 0.0020
# Epoch 185/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0068 - val_loss: 0.0020
# Epoch 186/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0067 - val_loss: 0.0019
# Epoch 187/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0056 - val_loss: 0.0020
# Epoch 188/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0041 - val_loss: 0.0019
# Epoch 189/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0081 - val_loss: 0.0019
# Epoch 190/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0078 - val_loss: 0.0019
# Epoch 191/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0089 - val_loss: 0.0019
# Epoch 192/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0060 - val_loss: 0.0019
# Epoch 193/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0063 - val_loss: 0.0019
# Epoch 194/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0060 - val_loss: 0.0020
# Epoch 195/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0052 - val_loss: 0.0019
# Epoch 196/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0061 - val_loss: 0.0019
# Epoch 197/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0087 - val_loss: 0.0019
# Epoch 198/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0052 - val_loss: 0.0019
# Epoch 199/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0064 - val_loss: 0.0018
# Epoch 200/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0083 - val_loss: 0.0018
# Epoch 201/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0068 - val_loss: 0.0018
# Epoch 202/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0072 - val_loss: 0.0018
# Epoch 203/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0065 - val_loss: 0.0018
# Epoch 204/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0062 - val_loss: 0.0019
# Epoch 205/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0044 - val_loss: 0.0019
# Epoch 206/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0073 - val_loss: 0.0019
# Epoch 207/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0065 - val_loss: 0.0019
# Epoch 208/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0065 - val_loss: 0.0019
# Epoch 209/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0033 - val_loss: 0.0019
# Epoch 210/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0056 - val_loss: 0.0019
# Epoch 211/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0070 - val_loss: 0.0019
# Epoch 212/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0076 - val_loss: 0.0018
# Epoch 213/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0064 - val_loss: 0.0018
# Epoch 214/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0054 - val_loss: 0.0018
# Epoch 215/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0063 - val_loss: 0.0017
# Epoch 216/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0050 - val_loss: 0.0018
# Epoch 217/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0093 - val_loss: 0.0020
# Epoch 218/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0075 - val_loss: 0.0018
# Epoch 219/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0069 - val_loss: 0.0018
# Epoch 220/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0064 - val_loss: 0.0018
# Epoch 221/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0072 - val_loss: 0.0017
# Epoch 222/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0054 - val_loss: 0.0017
# Epoch 223/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0049 - val_loss: 0.0017
# Epoch 224/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0075 - val_loss: 0.0017
# Epoch 225/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0059 - val_loss: 0.0017
# Epoch 226/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0062 - val_loss: 0.0018
# Epoch 227/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0070 - val_loss: 0.0017
# Epoch 228/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0055 - val_loss: 0.0017
# Epoch 229/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0050 - val_loss: 0.0017
# Epoch 230/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0085 - val_loss: 0.0017
# Epoch 231/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0071 - val_loss: 0.0018
# Epoch 232/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0075 - val_loss: 0.0017
# Epoch 233/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0075 - val_loss: 0.0017
# Epoch 234/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0049 - val_loss: 0.0017
# Epoch 235/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0050 - val_loss: 0.0017
# Epoch 236/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0066 - val_loss: 0.0017
# Epoch 237/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0060 - val_loss: 0.0017
# Epoch 238/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0050 - val_loss: 0.0017
# Epoch 239/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0068 - val_loss: 0.0017
# Epoch 240/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0070 - val_loss: 0.0017
# Epoch 241/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0056 - val_loss: 0.0018
# Epoch 242/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0056 - val_loss: 0.0018
# Epoch 243/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0064 - val_loss: 0.0018
# Epoch 244/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0066 - val_loss: 0.0016
# Epoch 245/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0055 - val_loss: 0.0018
# Epoch 246/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0062 - val_loss: 0.0018
# Epoch 247/420
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0068 - val_loss: 0.0017
# Epoch 248/420
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0080 - val_loss: 0.0017
# Epoch 249/420
# 11/11 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0017
# Epoch 250/420
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0074 - val_loss: 0.0017
# Epoch 251/420
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0092 - val_loss: 0.0017
# Epoch 252/420
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0069 - val_loss: 0.0017
# Epoch 253/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0058 - val_loss: 0.0017
# Epoch 254/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0053 - val_loss: 0.0017
# Epoch 255/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0068 - val_loss: 0.0017
# Epoch 256/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0066 - val_loss: 0.0017
# Epoch 257/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0051 - val_loss: 0.0016
# Epoch 258/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0070 - val_loss: 0.0016
# Epoch 259/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0052 - val_loss: 0.0016
# Epoch 260/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0072 - val_loss: 0.0016
# Epoch 261/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0058 - val_loss: 0.0016
# Epoch 262/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0075 - val_loss: 0.0016
# Epoch 263/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0067 - val_loss: 0.0016
# Epoch 264/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0063 - val_loss: 0.0016
# Epoch 265/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0068 - val_loss: 0.0016
# Epoch 266/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0055 - val_loss: 0.0016
# Epoch 267/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0058 - val_loss: 0.0016
# Epoch 268/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0072 - val_loss: 0.0017
# Epoch 269/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0055 - val_loss: 0.0017
# Epoch 270/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0070 - val_loss: 0.0017
# Epoch 271/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0066 - val_loss: 0.0016
# Epoch 272/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0049 - val_loss: 0.0016
# Epoch 273/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0049 - val_loss: 0.0015
# Epoch 274/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0069 - val_loss: 0.0015
# Epoch 275/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0058 - val_loss: 0.0016
# Epoch 276/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0061 - val_loss: 0.0017
# Epoch 277/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0051 - val_loss: 0.0017
# Epoch 278/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0075 - val_loss: 0.0017
# Epoch 279/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0074 - val_loss: 0.0016
# Epoch 280/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0054 - val_loss: 0.0016
# Epoch 281/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0058 - val_loss: 0.0016
# Epoch 282/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0056 - val_loss: 0.0016
# Epoch 283/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0062 - val_loss: 0.0016
# Epoch 284/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0057 - val_loss: 0.0016
# Epoch 285/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0057 - val_loss: 0.0016
# Epoch 286/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0070 - val_loss: 0.0016
# Epoch 287/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0060 - val_loss: 0.0016
# Epoch 288/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0057 - val_loss: 0.0016
# Epoch 289/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0055 - val_loss: 0.0016
# Epoch 290/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0064 - val_loss: 0.0016
# Epoch 291/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0048 - val_loss: 0.0017
# Epoch 292/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0062 - val_loss: 0.0016
# Epoch 293/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0068 - val_loss: 0.0016
# Epoch 294/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0044 - val_loss: 0.0016
# Epoch 295/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0055 - val_loss: 0.0015
# Epoch 296/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0052 - val_loss: 0.0015
# Epoch 297/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0074 - val_loss: 0.0015
# Epoch 298/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0079 - val_loss: 0.0017
# Epoch 299/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0095 - val_loss: 0.0017
# Epoch 300/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0063 - val_loss: 0.0017
# Epoch 301/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0060 - val_loss: 0.0016
# Epoch 302/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0066 - val_loss: 0.0017
# Epoch 303/420
# 11/11 [==============================] - 0s 13ms/step - loss: 0.0060 - val_loss: 0.0017
# Epoch 304/420
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0049 - val_loss: 0.0018
# Epoch 305/420
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0062 - val_loss: 0.0017
# Epoch 306/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0051 - val_loss: 0.0017
# Epoch 307/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0063 - val_loss: 0.0016
# Epoch 308/420
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0061 - val_loss: 0.0016
# Epoch 309/420
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0056 - val_loss: 0.0015
# Epoch 310/420
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0055 - val_loss: 0.0015
# Epoch 311/420
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0056 - val_loss: 0.0015
# Epoch 312/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0061 - val_loss: 0.0015
# Epoch 313/420
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0054 - val_loss: 0.0015
# Epoch 314/420
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0037 - val_loss: 0.0015
# Epoch 315/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0095 - val_loss: 0.0015
# Epoch 316/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0079 - val_loss: 0.0015
# Epoch 317/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0066 - val_loss: 0.0015
# Epoch 318/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0015
# Epoch 319/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0068 - val_loss: 0.0015
# Epoch 320/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0041 - val_loss: 0.0016
# Epoch 321/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0068 - val_loss: 0.0016
# Epoch 322/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0047 - val_loss: 0.0016
# Epoch 323/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0072 - val_loss: 0.0016
# Epoch 324/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0053 - val_loss: 0.0016
# Epoch 325/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0093 - val_loss: 0.0016
# Epoch 326/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0069 - val_loss: 0.0015
# Epoch 327/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0064 - val_loss: 0.0015
# Epoch 328/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0061 - val_loss: 0.0015
# Epoch 329/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 330/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0040 - val_loss: 0.0015
# Epoch 331/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0049 - val_loss: 0.0015
# Epoch 332/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0044 - val_loss: 0.0016
# Epoch 333/420
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0050 - val_loss: 0.0016
# Epoch 334/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0016
# Epoch 335/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0069 - val_loss: 0.0015
# Epoch 336/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0045 - val_loss: 0.0015
# Epoch 337/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0099 - val_loss: 0.0014
# Epoch 338/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0052 - val_loss: 0.0014
# Epoch 339/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0049 - val_loss: 0.0015
# Epoch 340/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0054 - val_loss: 0.0016
# Epoch 341/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0068 - val_loss: 0.0016
# Epoch 342/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0042 - val_loss: 0.0015
# Epoch 343/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0070 - val_loss: 0.0015
# Epoch 344/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0065 - val_loss: 0.0015
# Epoch 345/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0062 - val_loss: 0.0015
# Epoch 346/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0056 - val_loss: 0.0015
# Epoch 347/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0053 - val_loss: 0.0015
# Epoch 348/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0072 - val_loss: 0.0014
# Epoch 349/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0084 - val_loss: 0.0014
# Epoch 350/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0050 - val_loss: 0.0014
# Epoch 351/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0046 - val_loss: 0.0015
# Epoch 352/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0050 - val_loss: 0.0014
# Epoch 353/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0050 - val_loss: 0.0014
# Epoch 354/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0042 - val_loss: 0.0014
# Epoch 355/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0054 - val_loss: 0.0014
# Epoch 356/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0057 - val_loss: 0.0015
# Epoch 357/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0058 - val_loss: 0.0016
# Epoch 358/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0047 - val_loss: 0.0016
# Epoch 359/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0067 - val_loss: 0.0015
# Epoch 360/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0060 - val_loss: 0.0015
# Epoch 361/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0053 - val_loss: 0.0015
# Epoch 362/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0082 - val_loss: 0.0015
# Epoch 363/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0081 - val_loss: 0.0015
# Epoch 364/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0065 - val_loss: 0.0015
# Epoch 365/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0068 - val_loss: 0.0015
# Epoch 366/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0074 - val_loss: 0.0014
# Epoch 367/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0039 - val_loss: 0.0015
# Epoch 368/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0066 - val_loss: 0.0015
# Epoch 369/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0065 - val_loss: 0.0015
# Epoch 370/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0066 - val_loss: 0.0016
# Epoch 371/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0067 - val_loss: 0.0016
# Epoch 372/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0081 - val_loss: 0.0016
# Epoch 373/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0056 - val_loss: 0.0016
# Epoch 374/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0053 - val_loss: 0.0016
# Epoch 375/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0060 - val_loss: 0.0015
# Epoch 376/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0064 - val_loss: 0.0015
# Epoch 377/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0069 - val_loss: 0.0015
# Epoch 378/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0049 - val_loss: 0.0014
# Epoch 379/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0075 - val_loss: 0.0014
# Epoch 380/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0054 - val_loss: 0.0014
# Epoch 381/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0042 - val_loss: 0.0014
# Epoch 382/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0058 - val_loss: 0.0014
# Epoch 383/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0049 - val_loss: 0.0014
# Epoch 384/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0065 - val_loss: 0.0014
# Epoch 385/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 386/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0074 - val_loss: 0.0015
# Epoch 387/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0066 - val_loss: 0.0015
# Epoch 388/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0064 - val_loss: 0.0016
# Epoch 389/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0056 - val_loss: 0.0016
# Epoch 390/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0054 - val_loss: 0.0015
# Epoch 391/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0056 - val_loss: 0.0015
# Epoch 392/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0049 - val_loss: 0.0015
# Epoch 393/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0054 - val_loss: 0.0015
# Epoch 394/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0039 - val_loss: 0.0014
# Epoch 395/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0066 - val_loss: 0.0015
# Epoch 396/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0050 - val_loss: 0.0014
# Epoch 397/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0075 - val_loss: 0.0014
# Epoch 398/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0084 - val_loss: 0.0014
# Epoch 399/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0014
# Epoch 400/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0067 - val_loss: 0.0014
# Epoch 401/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0057 - val_loss: 0.0017
# Epoch 402/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0053 - val_loss: 0.0017
# Epoch 403/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0052 - val_loss: 0.0016
# Epoch 404/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0073 - val_loss: 0.0014
# Epoch 405/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0088 - val_loss: 0.0015
# Epoch 406/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0046 - val_loss: 0.0015
# Epoch 407/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0050 - val_loss: 0.0015
# Epoch 408/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0074 - val_loss: 0.0015
# Epoch 409/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0015
# Epoch 410/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 411/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0041 - val_loss: 0.0015
# Epoch 412/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0084 - val_loss: 0.0013
# Epoch 413/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0062 - val_loss: 0.0014
# Epoch 414/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0064 - val_loss: 0.0015
# Epoch 415/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0058 - val_loss: 0.0016
# Epoch 416/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0057 - val_loss: 0.0015
# Epoch 417/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0056 - val_loss: 0.0015
# Epoch 418/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0073 - val_loss: 0.0014
# Epoch 419/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0059 - val_loss: 0.0015
# Epoch 420/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0045 - val_loss: 0.0015
# Saved model to disk
# Loaded model from disk

# %% [markdown]
# Let's plot the dynamic of loss and val loss like in the previous case.

# %%
plt.figure()
plt.plot(history['loss'], label='train')
plt.plot(history['val_loss'], label='test')
plt.ylabel('loss')
plt.xlabel('epoch')

plt.legend()
plt.show()

# %% [markdown]
# Let's calculate our forecast.

# %%
res_tr_LSTM = model.predict(train_x_LSTM)
res_ts_LSTM = model.predict(test_x_LSTM)
res_train_LSTM=scaler_y.inverse_transform(res_tr_LSTM).flatten()
res_test_LSTM=scaler_y.inverse_transform(res_ts_LSTM).flatten()

# %% [markdown]
# And accuracy:

# %%
print("Correlation train", np.corrcoef(res_train, res_train_LSTM)[0,1])
print("Correlation train", np.corrcoef(res_test, res_test_LSTM)[0,1])
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, res_test_LSTM))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, res_test_LSTM))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, res_test_LSTM)))
# Out:
# Correlation train 0.9928495964501599
# Correlation train 0.9766580400384832
# Mean Absolute Error: 52680.85382168928
# Mean Squared Error: 8396806269.492304
# Root Mean Squared Error: 91634.08901436356

# %% [markdown]
# As you can see, the forecast results of the test data set are much better than ones of the previous models. Let's visualize these 3 results:

# %%
res_pred_test_ln = pd.Series(y_pred_test_ln, name = 'Predicted test Linear Model')
res_pred_test_ANN = pd.Series(res_test_ANN, name = 'Predicted test ANN')
res_pred_test_LSTM = pd.Series(res_test_LSTM, name = 'Predicted test LSTM')

df_2 = pd.DataFrame({'Actual test': res_test, 'Linear Model': res_pred_test_ln, 'ANN Model': res_pred_test_ANN,  'LSTM Model': res_pred_test_LSTM,})
df_2.index = dataset.index[len(dataset)-len(res_test):]
df_2.plot()
df_2 = pd.DataFrame({'Actual test': res_test, 'Linear Model': res_pred_test_ln,})
df_2.index = dataset.index[len(dataset)-len(res_test):]
df_2.plot()
df_2 = pd.DataFrame({'Actual test': res_test, 'LSTM Model': res_pred_test_LSTM,})
df_2.index = dataset.index[len(dataset)-len(res_test):]
df_2.plot()
df_2 = pd.DataFrame({'Actual test': res_test,'ANN Model': res_pred_test_ANN,})
df_2.index = dataset.index[len(dataset)-len(res_test):]
df_2.plot()
plt.show()

# %% [markdown]
# As you can see, an LSTM model makes a perfect forecast. A Linear Regression is the fastest forecasting model.
