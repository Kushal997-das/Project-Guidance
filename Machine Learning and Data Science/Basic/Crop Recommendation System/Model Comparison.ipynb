# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Test Accuracy

test=[0.9939393939393939,0.9924,0.9621212121212122,0.9075757575757576,0.9833333333333333]
label=["Random Forest","Naive Bayes","Logistic Regression","Decision Tree","SVM"]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=[6,4],dpi = 100)
plt.title('Test Accuracies')
plt.xlabel('Accuracy')
plt.ylabel('Type')
sns.barplot(x = test,y = label,palette="dark")
plt.xlim(0.5,1)
# Out:
# (0.5, 1.0)

# %%
# CV Accuracy
cv=[0.9927272727272728,0.9950,0.9550000000000001,0.9154545454545454,0.9827272727272728]
label=["Random Forest","Naive Bayes","Logistic Regression","Decision Tree","SVM"]

# %%
plt.figure(figsize=[6,4],dpi = 100)
plt.title('Cross-Validation Accuracies')
plt.xlabel('Accuracy')
plt.ylabel('Type')
sns.barplot(x = cv,y = label,palette="dark")
plt.xlim(0.5,1)
# Out:
# (0.5, 1.0)

# %% [markdown]
# #### Final Choice : Random Forest
